# %% [markdown]
# # Perform GSEA using GSEAPY
#
# Following the potocol defined here: https://gseapy.readthedocs.io/en/latest/gseapy_tutorial.html#use-gsea-command-or-gsea

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina' # mac
import pandas as pd
import gseapy as gp
import numpy as np
import matplotlib.pyplot as plt

# %%
gp.__version__
# Out:
# '0.9.9'

# %%
def run_GSEA_gene(celltype,nperm=1000,rseed=1000,
             rnkfile="../dat/figdata/fig2_prom_ttest_res.csv",
             glist='../dat/glists/gsea_final.gmt',col=0,
             rank_metrics='odds',**kwargs):
    '''
    col=1 - Z, 0 - logFC
    '''

    gene_exp_alpha = pd.read_csv(rnkfile)[['celltype','gene',rank_metrics]]
            
    #gene_exp_alpha.head()
    rnk = gene_exp_alpha.loc[gene_exp_alpha["celltype"]==celltype].drop(columns='celltype').sort_values(by=rank_metrics)
    if(rank_metrics=='odds'):
        rnk['odds'] =np.log2(rnk['odds'])
        rnk=rnk.reset_index(drop=True)
        df=rnk.drop(columns='gene')        
        np.random.seed(seed=rseed)
        for i in  rnk.index[(rnk['odds']==np.inf).tolist()].tolist():
            rnk.iloc[i,1]= float(df[~df.isin([np.inf])].max(0)*(1+np.random.uniform()/100))

        for i in  rnk.index[(rnk['odds']==-np.inf).tolist()].tolist():
            rnk.iloc[i,1]= float(df[~df.isin([-np.inf])].min(0)*(1+np.random.uniform()/100))
        #rnk['odds']=rnk['odds']/max(abs(rnk['odds']))
        
    print(rnk.shape)
    print(rnk.head(1))
    print(rnk.tail(1))
    
    gs_res_a = gp.prerank(rnk=rnk, # or data='./P53_resampling_data.txt'
                     gene_sets=glist, # enrichr library names or gmt file
                     #set permutation_type to phenotype if samples >=15
                     permutation_num=nperm, # reduce number to speed up test
                     outdir=None,  # do not write output to disk
                     no_plot=True, # Skip plotting
                     #weighted_score_type=1,
                     #ascending=False,
                        seed=rseed,
                     min_size=1,
                     max_size=2100,
                     processes=8,**kwargs)
                     #format='png')
    return(gs_res_a)

# %% [markdown]
# ## Run

# %%
gs_res_a=run_GSEA_gene(celltype='alpha',nperm=6000)
gs_res_a.res2d.sort_index()
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: RuntimeWarning: divide by zero encountered in log2
# (21715, 2)
#      gene      odds
# 0  ZNF106 -5.977715
#           gene      odds
# 21714  PLEKHS1  4.845848
# 2019-10-14 23:11:54,161 Input gene rankings contains duplicated IDs, Only use the duplicated ID with highest value!
#                             es       nes      pval       fdr  geneset_size  \
# Term
# Alpha1                0.863048  3.211043  0.000000  0.000000           179
# Alpha2               -0.512263 -2.734020  0.000000  0.000000           500
# Beta sub1_xin         0.373673  0.892750  0.597269  0.685844            13
# Beta sub2_xin         0.324017  0.919542  0.580313  0.765849            28
# Beta sub4_xin        -0.308192 -1.630665  0.000000  0.026549           390
# Beta1                 0.787686  2.942638  0.000000  0.000000           178
# Beta2                -0.300245 -1.637208  0.000000  0.038125           682
# Mawla_Beta_1          0.494201  1.185830  0.278441  0.265913            14
# Mawla_Beta_2         -0.365183 -1.258804  0.153548  0.184395            38
# multi_correlated      0.378206  1.210986  0.196185  0.302347            57
# mutli_anticorrelated -0.254885 -0.987753  0.490222  0.474256            54
#
#                       matched_size  \
# Term
# Alpha1                         179
# Alpha2                         500
# Beta sub1_xin                   13
# Beta sub2_xin                   28
# Beta sub4_xin                  386
# Beta1                          176
# Beta2                          681
# Mawla_Beta_1                    13
# Mawla_Beta_2                    32
# multi_correlated                54
# mutli_anticorrelated            51
#
#                                                                   genes  \
# Term
# Alpha1                WWC1;DDC;INPP4B;SLC7A8;AL136376.1;OR4N2;SLC6A4...
# Alpha2                FOXK2;PPP4R1;SH3KBP1;SSH1;SUN1;IQSEC1;C7orf55-...
# Beta sub1_xin         FXYD2;RBP4;PPP1R1A;SCGB2A1;FFAR4;SCGN;PRSS23;T...
# Beta sub2_xin         PCP4;TFF3;PEMT;NPY;IAPP;RBP1;AP3B1;RPS4X;PAM;G...
# Beta sub4_xin         C1orf43;C12orf29;PSMF1;GDF15;ARG2;GCG;MMP7;SNX...
# Beta1                 WWC1;DDC;INPP4B;LDLRAD3;ARHGAP26;MGAT5;GSTZ1;M...
# Beta2                 MDC1;GLYR1;CD44;TNS3;MAML3;CEP350;SLCO3A1;ARG2...
# Mawla_Beta_1          IGSF1;G6PC2;IAPP;SORL1;CECR1;ASB9;EDN3;TSPAN1;...
# Mawla_Beta_2          CPA1;SERPINA1;NPY;SYNGR4;C10orf10;S100A11;PRG4...
# multi_correlated      WDR59;F3;BMP5;ATP1B1;SLC30A8;CMC1;CCDC57;CHGA;...
# mutli_anticorrelated  PSMB7;SLC9A3R1;RBP4;GET4;ATP5B;MAGEH1;EIF4EBP1...
#
#                                                             ledge_genes
# Term
# Alpha1                WWC1;DDC;INPP4B;SLC7A8;AL136376.1;OR4N2;SLC6A4...
# Alpha2                NAA50;SMARCD1;ANP32B;MXRA7;POLR3A;NCAM1;DENND2...
# Beta sub1_xin                     FXYD2;RBP4;PPP1R1A;SCGB2A1;FFAR4;SCGN
# Beta sub2_xin                                   PCP4;TFF3;PEMT;NPY;IAPP
# Beta sub4_xin         RPS19;SYF2;SRSF7;MANF;RAD23B;ARF4;RPS27L;DDIT4...
# Beta1                 WWC1;DDC;INPP4B;LDLRAD3;ARHGAP26;MGAT5;GSTZ1;M...
# Beta2                 CRTC2;SLC25A38;IFT172;FBXO30;SDC2;RAPH1;ACAP1;...
# Mawla_Beta_1                               IGSF1;G6PC2;IAPP;SORL1;CECR1
# Mawla_Beta_2                        ACTG1;HSPA6;PPY;GADD45B;IL11;HS3ST2
# multi_correlated      WDR59;F3;BMP5;ATP1B1;SLC30A8;CMC1;CCDC57;CHGA;...
# mutli_anticorrelated  SCAND1;MTHFD2;RSF1;SNRPB;TCEB2;COPS3;SNRNP40;N...

# %%
gs_res_b=run_GSEA_gene(celltype='beta',nperm=5000,rseed=3000)
gs_res_b.res2d.sort_index()
# Out:
# (21825, 2)
#    gene     odds
# 0  PDHX -5.19691
#         gene      odds
# 21824  TIGIT  5.021062
# 2019-10-14 12:45:01,021 Input gene rankings contains duplicated IDs, Only use the duplicated ID with highest value!
#                             es       nes      pval       fdr  geneset_size  \
# Term
# Alpha1                0.772896  2.571810  0.000000  0.000000           179
# Alpha2               -0.286097 -1.590795  0.000000  0.041097           500
# Beta sub1_xin         0.359062  0.825018  0.687208  0.796864            13
# Beta sub2_xin         0.569174  1.503907  0.037497  0.038715            28
# Beta sub3_xin         0.643159  1.398873  0.110706  0.059858            13
# Beta sub4_xin        -0.340284 -1.805740  0.000000  0.020323           390
# Beta1                 0.851367  2.842941  0.000000  0.000000           178
# Beta2                -0.483746       NaN       NaN  1.000000           682
# Mawla_Beta_1          0.621505  1.454054  0.066302  0.047146            14
# Mawla_Beta_2         -0.332739 -1.166957  0.224678  0.241730            38
# multi_correlated      0.399294  1.188604  0.231111  0.199106            57
# mutli_anticorrelated -0.405450 -1.624576  0.008568  0.049001            54
#
#                       matched_size  \
# Term
# Alpha1                         177
# Alpha2                         499
# Beta sub1_xin                   13
# Beta sub2_xin                   27
# Beta sub3_xin                   10
# Beta sub4_xin                  385
# Beta1                          178
# Beta2                          682
# Mawla_Beta_1                    14
# Mawla_Beta_2                    31
# multi_correlated                54
# mutli_anticorrelated            51
#
#                                                                   genes  \
# Term
# Alpha1                INPP4B;TLE3;MTCH1;CEP350;GSTZ1;CTBP1;SEPT9;DLG...
# Alpha2                TOM1L2;CKAP5;FBXL13;UCK2;TECR;C12orf65;SDK1;FA...
# Beta sub1_xin         PRSS23;FXYD2;SCGB2A1;FFAR4;RBP4;PPP1R1A;SCGN;A...
# Beta sub2_xin         PCP4;PEMT;AP3B1;ID1;STMN2;RBP1;TFF3;GNAS;IAPP;...
# Beta sub3_xin         INS;ASB9;DLK1;CHGA;LAMP1;IGFBP7;CPE;CKB;TIMP1;...
# Beta sub4_xin         PSMF1;WDR45B;HSPA9;ANXA2;ATP6V0D1;KRT8;ATP6V1H...
# Beta1                 RHBDL2;INPP4B;CCR8;CASR;ATF7IP;NPEPL1;INS;INS-...
# Beta2                 PRKCH;PGM1;CKAP5;RPS6KA5;ARAP3;ARID1B;CHKA;SUG...
# Mawla_Beta_1          SORL1;ASB9;HADH;G6PC2;IGSF1;IAPP;CECR1;PCSK1;T...
# Mawla_Beta_2          CPA1;SYNGR4;C10orf10;CTRB2;NPY;TMSB4X;SOD2;S10...
# multi_correlated      KCNMB2;WDR59;SLC30A8;AP3B1;PIGX;DMKN;F3;BMP5;S...
# mutli_anticorrelated  GET4;SLC9A3R1;RBP4;DHPS;ID2;H1F0;MAGEH1;SNF8;S...
#
#                                                             ledge_genes
# Term
# Alpha1                INPP4B;TLE3;MTCH1;CEP350;GSTZ1;CTBP1;SEPT9;DLG...
# Alpha2                EIF4A1;HOMER1;ECE1;GOT1;PLEKHH2;VDAC1;PRKCA;BD...
# Beta sub1_xin                           PRSS23;FXYD2;SCGB2A1;FFAR4;RBP4
# Beta sub2_xin         PCP4;PEMT;AP3B1;ID1;STMN2;RBP1;TFF3;GNAS;IAPP;...
# Beta sub3_xin                           INS;ASB9;DLK1;CHGA;LAMP1;IGFBP7
# Beta sub4_xin         ARID5B;EIF2S2;ZFAND2A;ARPP19;XBP1;TMEM258;U2AF...
# Beta1                 RHBDL2;INPP4B;CCR8;CASR;ATF7IP;NPEPL1;INS;INS-...
# Beta2                 TNPO1;MAP4;SLC25A25;B3GALNT2;USO1;WDSUB1;MSL2;...
# Mawla_Beta_1               SORL1;ASB9;HADH;G6PC2;IGSF1;IAPP;CECR1;PCSK1
# Mawla_Beta_2          SAT1;SST;TIMP1;NAMPT;PTGS2;BIRC3;SPP1;GADD45B;...
# multi_correlated      KCNMB2;WDR59;SLC30A8;AP3B1;PIGX;DMKN;F3;BMP5;S...
# mutli_anticorrelated  SEC13;ATP5B;DLD;RSF1;JTB;MRFAP1L1;DNAJC8;TCEB2...

# %%
gs_res_d=run_GSEA_gene(celltype='delta',nperm=5000,rseed=3000)
gs_res_d.res2d.sort_index()
# Out:
# (18547, 2)
#     gene      odds
# 0  TEKT3 -5.978187
#         gene      odds
# 18546  PPIL2  3.418173
# 2019-10-14 23:19:50,193 Input gene rankings contains duplicated IDs, Only use the duplicated ID with highest value!
#                             es       nes      pval       fdr  geneset_size  \
# Term
# Alpha1                0.591037  1.543987  0.000000  0.012080           179
# Alpha2                0.245361  0.649910  1.000000  1.000000           500
# Beta sub1_xin        -0.291108 -0.936816  0.531507  0.524362            13
# Beta sub2_xin         0.443777  1.057415  0.423659  0.894425            28
# Beta sub3_xin         0.658513  1.321366  0.085106  0.103502            13
# Beta sub4_xin         0.166042  0.437918  1.000000  0.998988           390
# Beta1                 0.587551  1.533408  0.000000  0.006701           178
# Beta2                 0.342990  0.911071  0.954400  1.000000           682
# Mawla_Beta_1          0.493192  1.047211  0.441973  0.781945            14
# Mawla_Beta_2          0.308591  0.745495  0.883527  1.000000            38
# multi_correlated      0.335050  0.840888  0.840345  1.000000            57
# mutli_anticorrelated  0.264983  0.666166  0.967716  1.000000            54
#
#                       matched_size  \
# Term
# Alpha1                         174
# Alpha2                         495
# Beta sub1_xin                   13
# Beta sub2_xin                   25
# Beta sub3_xin                    8
# Beta sub4_xin                  382
# Beta1                          173
# Beta2                          678
# Mawla_Beta_1                    11
# Mawla_Beta_2                    29
# multi_correlated                54
# mutli_anticorrelated            50
#
#                                                                   genes  \
# Term
# Alpha1                LMO7;BACE1;TPM3;SH3KBP1;ABCC8;SH3TC1;HEG1;MYO3...
# Alpha2                FAM214A;SH3KBP1;HAGH;SDCBP2;STXBP1;MXRA7;UPF1;...
# Beta sub1_xin         SCGB2A1;PRSS23;TAGLN2;FFAR4;SCGN;FXYD2;TUBB2A;...
# Beta sub2_xin         GNAS;PEMT;TFF3;NPY;SEC11C;STMN2;RBP1;PAM;CDKN1...
# Beta sub3_xin                 IGFBP7;LAMP1;CHGB;ASB9;TIMP1;CPE;CHGA;CKB
# Beta sub4_xin         BUD31;MMP7;TRA2B;HAX1;HLA-E;TALDO1;BAX;EMC2;YW...
# Beta1                 BACE1;FUT9;SAMD11;RP11-723O4.6;SLC39A11;GPD1L;...
# Beta2                 MARS;ZBTB20;FOXP1;ATXN1;TOR1AIP1;ALDOA;MBIP;AR...
# Mawla_Beta_1          IGSF1;TSPAN1;EDN3;PCSK1;CDKN1C;MAFA;SORL1;ASB9...
# Mawla_Beta_2          S100A11;SYNGR4;PTPRH;NPY;CPB1;CTRB2;SERPINA1;S...
# multi_correlated      KCNMB2;SLC16A9;SYN1;PAXBP1;PIGX;NEO1;RAI1;IFI6...
# mutli_anticorrelated  SNF8;H1F0;PSMB7;DHPS;PFN1;MRFAP1L1;SLC3A2;GYG1...
#
#                                                             ledge_genes
# Term
# Alpha1                LMO7;BACE1;TPM3;SH3KBP1;ABCC8;SH3TC1;HEG1;MYO3...
# Alpha2                FAM214A;SH3KBP1;HAGH;SDCBP2;STXBP1;MXRA7;UPF1;...
# Beta sub1_xin                           RBP4;ASCL2;PPP1R1A;TUBA4A;TMED6
# Beta sub2_xin         GNAS;PEMT;TFF3;NPY;SEC11C;STMN2;RBP1;PAM;CDKN1...
# Beta sub3_xin                                              IGFBP7;LAMP1
# Beta sub4_xin         BUD31;MMP7;TRA2B;HAX1;HLA-E;TALDO1;BAX;EMC2;YW...
# Beta1                 BACE1;FUT9;SAMD11;RP11-723O4.6;SLC39A11;GPD1L;...
# Beta2                 MARS;ZBTB20;FOXP1;ATXN1;TOR1AIP1;ALDOA;MBIP;AR...
# Mawla_Beta_1                             IGSF1;TSPAN1;EDN3;PCSK1;CDKN1C
# Mawla_Beta_2                        S100A11;SYNGR4;PTPRH;NPY;CPB1;CTRB2
# multi_correlated      KCNMB2;SLC16A9;SYN1;PAXBP1;PIGX;NEO1;RAI1;IFI6...
# mutli_anticorrelated  SNF8;H1F0;PSMB7;DHPS;PFN1;MRFAP1L1;SLC3A2;GYG1...

# %%
gs_res_b.res2d[['es','nes','pval','fdr']].to_csv('../dat/figdata/GSEA_beta_res_final.csv')
gs_res_a.res2d[['es','nes','pval','fdr']].to_csv('../dat/figdata/GSEA_alpha_res_final.csv')
gs_res_d.res2d[['es','nes','pval','fdr']].to_csv('../dat/figdata/GSEA_delta_res_final.csv')
