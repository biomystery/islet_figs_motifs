# %% [markdown]
# # Perform GSEA using GSEAPY
#
# Following the potocol defined here: https://gseapy.readthedocs.io/en/latest/gseapy_tutorial.html#use-gsea-command-or-gsea

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina' # mac
import pandas as pd
import gseapy as gp
import matplotlib.pyplot as plt

# %%
gp.__version__
# Out:
# '0.9.9'

# %% [markdown]
# ## 1. Prepare expression file
# In our case, the expression file is the percentage of cells inside each pseudostate **bin**

# %%
gene_exp_alpha = pd.read_table("./dat/alpha.100_bin_pseudotime_raw.promoter.txt").transpose()
gene_exp_alpha.head()
# Out:
#           0    1    2    3         4         5         6         7         8   \
# SAMD11   0.0  0.0  0.0  0.0  0.000000  0.000000  0.000000  0.389105  0.469484
# NOC2L    0.0  0.0  0.0  0.0  2.941176  4.477612  4.069767  4.280156  3.286385
# KLHL17   0.0  0.0  0.0  0.0  2.941176  1.492537  2.325581  0.000000  0.938967
# PLEKHN1  0.0  0.0  0.0  0.0  2.941176  0.000000  2.325581  0.389105  1.877934
# HES4     0.0  0.0  0.0  0.0  2.941176  2.985075  2.906977  1.945525  5.164319
#
#                9   ...          90         91         92     93         94  \
# SAMD11   0.000000  ...    0.000000   0.000000   0.000000   0.00   1.724138
# NOC2L    4.109589  ...    4.848485   7.333333   5.607477   8.75   5.172414
# KLHL17   1.369863  ...    1.212121   1.333333   0.934579   5.00   3.448276
# PLEKHN1  4.109589  ...    1.818182   4.666667   2.803738   6.25   8.620690
# HES4     4.109589  ...   12.121212  16.000000  14.953271  17.50  18.965517
#
#              95         96    97   98    99
# SAMD11    0.000   0.000000   0.0  0.0   0.0
# NOC2L     9.375   5.263158  30.0  0.0   0.0
# KLHL17    3.125  10.526316   0.0  0.0   0.0
# PLEKHN1   3.125   5.263158  30.0  0.0  50.0
# HES4     31.250  21.052632  30.0  0.0   0.0
#
# [5 rows x 100 columns]

# %% [markdown]
# ## 2. Phenotype file (.cls)
# - The first line specify the total samples and phenotype numbers. Leave number 1 alway be 1.
# - The second line specify the phenotype class(name).
# - The third line specify column attributes in setp 1.

# %%
threshold_alpha=round(1.4265/1.9208*100)
threshold_alpha
# Out:
# 74

# %%
with open('./dat/pheno.cls',"w") as f:
    f.write("100 2 1\n")
    f.write("#A1 A2\n")
    f.write("A1 "*threshold_alpha+("A2 "*(100-threshold_alpha)).rstrip()+"\n")

# %%
phenoA, phenoB, class_vector =  gp.parser.gsea_cls_parser("./dat/pheno.cls")
#class_vector used to indicate group attributes for each sample
print(class_vector)
# Out:
# ['A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A2', 'A2', 'A2', 'A2', 'A2', 'A2', 'A2', 'A2', 'A2', 'A2', 'A2', 'A2', 'A2', 'A2', 'A2', 'A2', 'A2', 'A2', 'A2', 'A2', 'A2', 'A2', 'A2', 'A2', 'A2', 'A2']

# %%
print("positively correlated: ", phenoA)
# Out:
# positively correlated:  A1

# %%
print("negtively correlated: ", phenoB)
# Out:
# negtively correlated:  A2

# %% [markdown]
# ## 3. define gene sets
#
# In our case, we will use the beta gene sets from the three literature. And save to [gmt](http://software.broadinstitute.org/cancer/software/gsea/wiki/index.php/Data_formats#GMT:_Gene_Matrix_Transposed_file_format_.28.2A.gmt.29) format.
#
# It was done in another [notebook](./compare_with_previous_glists.ipynb)

# %% [markdown]
# ## 4. Run gsea

# %%
# run gsea
# enrichr libraries are supported by gsea module. Just provide the name

gs_res = gp.gsea(data=gene_exp_alpha, # or data='./P53_resampling_data.txt'
                 gene_sets='./dat/glists/gsea.gmt', # enrichr library names or gmt file
                 cls= class_vector, # cls=class_vector
                 #set permutation_type to phenotype if samples >=15
                 permutation_type='phenotype',
                 permutation_num=100, # reduce number to speed up test
                 outdir=None,  # do not write output to disk
                 no_plot=True, # Skip plotting
                 method='signal_to_noise',
                 min_size=0,
                 max_size=4000,
                 processes=4,
                 format='png')

# %%
#access the dataframe results throught res2d attribute
gs_res.res2d
# Out:
#                         es       nes      pval       fdr  geneset_size  \
# Term
# A1_alpha         -0.894123 -2.610481  0.000000  0.000000          3526
# A2_alpha          0.886078  3.026559  0.000000  0.000000           240
# B1_beta          -0.552261 -1.856483  0.000000  0.000000           420
# B2_beta           0.616985  2.076272  0.000000  0.000000            75
# ST8SIA1+_dorrell -0.363776 -1.415479  0.100000  0.178862            46
# Beta sub4_xin    -0.382072 -1.302898  0.000000  0.268293           390
# Beta sub1_xin     0.397355  1.142357  0.200000  0.275862            13
# mature_bader     -0.312947 -1.160683  0.111111  0.417344            72
# immature_bader   -0.330818 -1.198686  0.100000  0.465041           579
# CD9-_dorrell     -0.236951 -0.976613  0.285714  0.817654            57
# ST8SIA1-_dorrell -0.168559 -0.586412  0.900000  0.975610            65
# CD9+_dorrell     -0.244071 -0.793476  0.700000  1.000000            45
# Beta sub3_xin    -0.331681 -0.718835  0.857143  1.000000            13
# Beta sub2_xin    -0.220211 -0.694926  0.888889  1.000000            28
#
#                   matched_size  \
# Term
# A1_alpha                  3526
# A2_alpha                   237
# B1_beta                    420
# B2_beta                     74
# ST8SIA1+_dorrell            35
# Beta sub4_xin              323
# Beta sub1_xin               11
# mature_bader                42
# immature_bader             441
# CD9-_dorrell                46
# ST8SIA1-_dorrell            54
# CD9+_dorrell                34
# Beta sub3_xin                9
# Beta sub2_xin               25
#
#                                                               genes  \
# Term
# A1_alpha          FFAR4;SLC35D3;UGGT2;RNPS1;GNL3;HEATR5A;REEP5;S...
# A2_alpha          TMCO2;MAPK10;GALNT8;C8B;GCK;GCG;PGAM2;SYT10;SM...
# B1_beta           CAST;NT5M;ZNF684;PSAT1;SLC7A11;SCEL;PRMT2;PLA2...
# B2_beta           G6PC2;SLC25A34;NEUROD1;KCNA5;IGFBP1;RSPO3;MS4A...
# ST8SIA1+_dorrell  TFF3;KCNJ8;OPCML;ATP8A2;MYOM1;GAP43;SULF2;RBM4...
# Beta sub4_xin     GCG;PSMF1;MMP7;AUP1;HSPD1;DNAJC12;LURAP1L;CCT6...
# Beta sub1_xin     SCGB2A1;RBP4;FFAR4;PPP1R1A;SCGN;FXYD2;TUBA4A;P...
# mature_bader      SRGAP3;NPFFR2;GPR83;SYTL2;NHSL1;SYT1;SVEP1;ITG...
# immature_bader    GCK;PSMF1;G6PC2;SV2A;SYTL4;CDHR1;SLC7A8;GPC4;D...
# CD9-_dorrell      NPY;ADAMTS5;SOX5;LRRTM4;STMN2;PCDH7;COL24A1;SE...
# ST8SIA1-_dorrell  G6PC2;NEUROD1;SCGB2A1;GREM1;SLC27A2;HCN4;SLC5A...
# CD9+_dorrell      GNAL;KCNA5;RBP4;PPP1R1A;ZFP36;AK5;CD9;NPC1L1;P...
# Beta sub3_xin      CHGA;DLK1;ASB9;IGFBP7;PRSS1;TIMP1;CKB;LAMP1;CHGB
# Beta sub2_xin     TFF3;NPY;STMN2;RBP1;GPX3;IAPP;SCG2;ID1;SIX3;SE...
#
#                                                         ledge_genes
# Term
# A1_alpha          COBLL1;USP9X;SETBP1;TRIM41;ZNF326;ACSL1;C15orf...
# A2_alpha          TMCO2;MAPK10;GALNT8;C8B;GCK;GCG;PGAM2;SYT10;SM...
# B1_beta           PPA1;RAB3GAP1;TRPC4AP;FBXO11;SLC2A11;SNX27;MRO...
# B2_beta           G6PC2;SLC25A34;NEUROD1;KCNA5;IGFBP1;RSPO3;MS4A...
# ST8SIA1+_dorrell  DAB1;CREB3L1;KCND3;TMEM130;CHD5;NEFM;PDK4;CDR2...
# Beta sub4_xin     SNRPB2;LMNA;CNBP;MANF;MYL12B;TAF12;C1orf52;SAP...
# Beta sub1_xin                       SCGB2A1;RBP4;FFAR4;PPP1R1A;SCGN
# mature_bader      C19orf57;KCNV1;N4BP3;PLD1;RAD54L;SLC6A12;GRIA3...
# immature_bader    BBS9;STAU1;DUSP12;MRPS18A;SRP9;DVL3;ENSA;KLHL2...
# CD9-_dorrell      MLLT3;CNKSR2;PLK2;STARD9;PTPN13;ASXL2;ACVR1C;K...
# ST8SIA1-_dorrell  HBEGF;MT1X;OXCT1;NFIX;BNIP3;MARK1;LRRFIP1;MAFB...
# CD9+_dorrell      RIPK4;MCOLN3;BMP2;AKAP13;RAI14;TTC9;SERPINE2;A...
# Beta sub3_xin                                        CKB;LAMP1;CHGB
# Beta sub2_xin     GNAS;PCP4;BTG2;NENF;RGS16;PAM;AP3B1;CDKN1C;PEM...

# %% [markdown]
# ### show the results
# The **gsea** module will generate heatmap for genes in each gene sets in the backgroud.
# But if you need to do it yourself, use the code below

# %%
from gseapy.plot import gseaplot, heatmap
terms = gs_res.res2d.index
for i in range(len(terms)):
    gseaplot(gs_res.ranking, term=terms[i], **gs_res.results[terms[i]])
