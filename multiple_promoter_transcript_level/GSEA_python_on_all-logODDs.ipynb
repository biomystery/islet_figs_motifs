# %% [markdown]
# # Perform GSEA using GSEAPY
#
# Following the potocol defined here: https://gseapy.readthedocs.io/en/latest/gseapy_tutorial.html#use-gsea-command-or-gsea

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina' # mac
import pandas as pd
import gseapy as gp
import numpy as np
import matplotlib.pyplot as plt

# %%
gp.__version__
# Out:
# '0.9.9'

# %%
def run_GSEA_gene(celltype,nperm=1000,
             rnkfile="../dat/figdata/fig2_prom_ttest_res_genelevel.csv",
             glist='../dat/glists/gsea.gmt',
                 rank_metrics='mlog10P'):
    

    gene_exp_alpha = pd.read_csv(rnkfile)[['celltype','gene',rank_metrics]]
            
    #gene_exp_alpha.head()
    rnk = gene_exp_alpha.loc[gene_exp_alpha["celltype"]==celltype].drop(columns='celltype').sort_values(by=rank_metrics)
    if(rank_metrics=='odds'):
        rnk['odds'] =np.log2(rnk['odds'])
        rnk=rnk.reset_index(drop=True)
        df=rnk.drop(columns='gene')        
        
        for i in  rnk.index[(rnk['odds']==np.inf).tolist()].tolist():
            rnk.iloc[i,1]= float(df[~df.isin([np.inf])].max(0)*(1+np.random.uniform()/100))

        for i in  rnk.index[(rnk['odds']==-np.inf).tolist()].tolist():
            rnk.iloc[i,1]= float(df[~df.isin([-np.inf])].min(0)*(1+np.random.uniform()/100))
        
        
    print(rnk.shape)
    print(rnk.head(1))
    print(rnk.tail(1))

    gs_res_a = gp.prerank(rnk=rnk, # or data='./P53_resampling_data.txt'
                     gene_sets=glist, # enrichr library names or gmt file
                     #set permutation_type to phenotype if samples >=15
                     permutation_num=nperm, # reduce number to speed up test
                     outdir=None,  # do not write output to disk
                     no_plot=True, # Skip plotting
                     #weighted_score_type=1,
                     #ascending=False,
                        seed=1000,
                     min_size=1,
                     max_size=5000,
                     processes=8)
                     #format='png')
    return(gs_res_a)

# %% [markdown]
# ## alpha

# %%
gs_res_a=run_GSEA_gene('alpha',
                       glist='../dat/glists/gsea_all.gmt',
                       rnkfile='../dat/figdata/fig2_prom_ttest_res.csv',rank_metrics='odds')
gs_res_a.res2d.sort_index()
# Out:
# /Users/frank/anaconda/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:12: RuntimeWarning: divide by zero encountered in log2
#   if sys.path[0] == '':
# (21715, 2)
#      gene     odds
# 0  ZNF106 -5.99124
#           gene      odds
# 21714  PLEKHS1  4.828911
# 2019-08-23 17:18:51,254 Input gene rankings contains duplicated IDs, Only use the duplicated ID with highest value!

# %% [markdown]
# ## beta

# %%
gs_res=run_GSEA_gene('beta')
gs_res.res2d.sort_index()
# Out:
# (12988,)
# gene
# SLC2A13   -40.521506
# Name: mlog10P, dtype: float64
# gene
# INS-IGF2    36.40042
# Name: mlog10P, dtype: float64
#                                              es       nes      pval       fdr  \
# Term
# Alpha-state 1 down                    -0.427283 -1.460995  0.000000  0.009524
# Alpha-state 1 down<-10                -0.590123 -1.715466  0.000000  0.001083
# Alpha-state 1 down<-5                 -0.453794 -1.535945  0.000000  0.007241
# Alpha-state 1 up                      -0.393280 -1.349153  0.000000  0.019915
# Alpha-state 1 up>10                   -0.409621 -1.392318  0.000000  0.014778
# Alpha-state 1 up>5                    -0.394016 -1.351553  0.000000  0.019858
# Alpha-state 2 down                    -0.428932 -1.461195  0.000000  0.009783
# Alpha-state 2 down<-10                -0.467624 -1.491781  0.001009  0.008018
# Alpha-state 2 down<-5                 -0.443755 -1.497586  0.000000  0.008090
# Alpha-state 2 up                      -0.400605 -1.368102  0.000000  0.017829
# Alpha-state 2 up>10                   -0.418411 -1.345965  0.011066  0.020057
# Alpha-state 2 up>5                    -0.395572 -1.336347  0.000000  0.020484
# Alpha-state 3 down                    -0.535820 -1.811141  0.000000  0.000619
# Alpha-state 3 down<-10                -0.636143 -1.333076  0.114094  0.020819
# Alpha-state 3 down<-5                 -0.534911 -1.748325  0.000000  0.000928
# Alpha-state 3 up                      -0.361131 -1.228276  0.000000  0.050895
# Alpha-state 3 up>10                    0.279748  1.130437  0.303030  0.316435
# Alpha-state 3 up>5                    -0.349270 -1.174094  0.017000  0.080906
# Alpha-state 4 down                    -0.426146 -1.461910  0.000000  0.010026
# Alpha-state 4 down<-10                -0.398837 -1.345291  0.000000  0.019854
# Alpha-state 4 down<-5                 -0.423709 -1.452912  0.000000  0.009828
# Alpha-state 4 up                      -0.444722 -1.521563  0.000000  0.007645
# Alpha-state 4 up>10                   -0.488947 -1.470961  0.007292  0.009322
# Alpha-state 4 up>5                    -0.445123 -1.511701  0.000000  0.007891
# Alpha-state 5 down                    -0.366388 -1.238596  0.000000  0.047309
# Alpha-state 5 down<-10                -0.332904 -1.084780  0.288442  0.203156
# Alpha-state 5 down<-5                 -0.334574 -1.119623  0.100000  0.137361
# Alpha-state 5 up                      -0.446525 -1.525870  0.000000  0.007659
# Alpha-state 5 up>10                   -0.567319 -1.646631  0.001068  0.002089
# Alpha-state 5 up>5                    -0.477955 -1.619561  0.000000  0.002642
# ...                                         ...       ...       ...       ...
# Alpha1                                 0.837166  3.758180  0.000000  0.000000
# Alpha2                                -0.695430 -2.369588  0.000000  0.000000
# Beta sub1_xin                         -0.287611 -0.660501  0.884945  0.983971
# Beta sub2_xin                          0.548305  1.753645  0.022059  0.026297
# Beta sub3_xin                          0.780771  2.084773  0.000000  0.001461
# Beta sub4_xin                         -0.508191 -1.688889  0.000000  0.001031
# Beta-state1 genesdown                 -0.446676 -1.509688  0.000000  0.007573
# Beta-state1 genesdown<-5              -0.440011 -1.417356  0.003030  0.012547
# Beta-state1 genesup                   -0.394790 -1.354486  0.000000  0.019913
# Beta-state1 genesup>5                 -0.392675 -1.339168  0.000000  0.020465
# Beta-state2 genesdown                 -0.414718 -1.414937  0.000000  0.012451
# Beta-state2 genesdown<-5              -0.446417 -1.501726  0.000000  0.007845
# Beta-state2 genesup                   -0.420684 -1.426756  0.000000  0.011662
# Beta-state2 genesup>5                 -0.421283 -1.408812  0.000000  0.012864
# Beta-state3 genesdown                 -0.419968 -1.440672  0.000000  0.010831
# Beta-state3 genesdown<-5              -0.403658 -1.376253  0.000000  0.016784
# Beta-state3 genesup                   -0.412284 -1.393944  0.000000  0.015008
# Beta-state3 genesup>5                 -0.443998 -1.439774  0.002010  0.010571
# Beta-state4 genesdown                 -0.390096 -1.315845  0.000000  0.024292
# Beta-state4 genesdown<-5              -0.325072 -1.083446  0.224000  0.202114
# Beta-state4 genesup                   -0.425730 -1.456143  0.000000  0.009781
# Beta-state4 genesup>5                 -0.439528 -1.491021  0.000000  0.007790
# Beta1                                  1.000000  4.501983  0.000000  0.000000
# Beta2                                 -1.000000 -3.366711  0.000000  0.000000
# ND_exocytosis_anticorrelated          -0.522876 -1.695510  0.000000  0.001160
# ND_exocytosis_anticorrelated_filtered -0.514801 -1.648265  0.000000  0.002279
# ND_exocytosis_correlated              -0.326755 -1.071926  0.305835  0.229253
# ND_exocytosis_correlated_filtered     -0.263773 -0.844543  0.811550  0.942576
# multi_correlated                       0.252755  0.997608  0.425000  0.430972
# mutli_anticorrelated                  -0.527939 -1.542249  0.004233  0.007360
#
#                                        geneset_size  matched_size  \
# Term
# Alpha-state 1 down                             2423          1949
# Alpha-state 1 down<-10                           61            48
# Alpha-state 1 down<-5                           828           663
# Alpha-state 1 up                               4578          3639
# Alpha-state 1 up>10                            1457          1174
# Alpha-state 1 up>5                             3807          3055
# Alpha-state 2 down                             1781          1436
# Alpha-state 2 down<-10                          170           132
# Alpha-state 2 down<-5                           857           678
# Alpha-state 2 up                               2262          1830
# Alpha-state 2 up>10                             194           152
# Alpha-state 2 up>5                             1111           889
# Alpha-state 3 down                              821           614
# Alpha-state 3 down<-10                           13             8
# Alpha-state 3 down<-5                           209           153
# Alpha-state 3 up                               1533          1296
# Alpha-state 3 up>10                              56            49
# Alpha-state 3 up>5                              694           594
# Alpha-state 4 down                             5779          4705
# Alpha-state 4 down<-10                          693           566
# Alpha-state 4 down<-5                          4360          3559
# Alpha-state 4 up                               2535          2002
# Alpha-state 4 up>10                              71            64
# Alpha-state 4 up>5                             1131           906
# Alpha-state 5 down                             1110           886
# Alpha-state 5 down<-10                          208           185
# Alpha-state 5 down<-5                           600           495
# Alpha-state 5 up                               1842          1483
# Alpha-state 5 up>10                              68            49
# Alpha-state 5 up>5                              746           594
# ...                                             ...           ...
# Alpha1                                          179            68
# Alpha2                                         1967          1575
# Beta sub1_xin                                    13            12
# Beta sub2_xin                                    28            17
# Beta sub3_xin                                    13             8
# Beta sub4_xin                                   390           355
# Beta-state1 genesdown                           981           788
# Beta-state1 genesdown<-5                        180           145
# Beta-state1 genesup                            3385          2699
# Beta-state1 genesup>5                          1870          1479
# Beta-state2 genesdown                          1784          1409
# Beta-state2 genesdown<-5                        683           536
# Beta-state2 genesup                            1397          1114
# Beta-state2 genesup>5                           670           527
# Beta-state3 genesdown                          4369          3505
# Beta-state3 genesdown<-5                       1877          1489
# Beta-state3 genesup                            1126           912
# Beta-state3 genesup>5                           221           184
# Beta-state4 genesdown                           989           807
# Beta-state4 genesdown<-5                        469           395
# Beta-state4 genesup                            2354          1897
# Beta-state4 genesup>5                          1083           852
# Beta1                                           178            89
# Beta2                                           682           501
# ND_exocytosis_anticorrelated                    250           204
# ND_exocytosis_anticorrelated_filtered           191           158
# ND_exocytosis_correlated                        311           216
# ND_exocytosis_correlated_filtered               182           123
# multi_correlated                                 57            40
# mutli_anticorrelated                             54            48
#
#                                                                                    genes  \
# Term
# Alpha-state 1 down                     GPD1L;CRADD;KCNA5;CCDC150;SLC38A4;PRKAB1;PLCL2...
# Alpha-state 1 down<-10                 EEF1A1;RPS26;GC;FOS;PTP4A1;YWHAQ;RPL21;RAB1A;N...
# Alpha-state 1 down<-5                  GPD1L;GPR27;EMB;FABP5;NHLRC3;TMEM5;TTC14;TCF20...
# Alpha-state 1 up                       INS;NPEPL1;G6PC2;DHRS2;IPO13;KCNK17;KLHDC4;MS4...
# Alpha-state 1 up>10                    INS;KCNK16;ABLIM2;CHGA;ATP1A1;REC8;PCSK1N;SYT1...
# Alpha-state 1 up>5                     INS;NPEPL1;G6PC2;DHRS2;IPO13;KCNK17;KCNK16;ETF...
# Alpha-state 2 down                     INS;KLHDC4;KCNK16;CHGA;ATP1A1;WWC1;REC8;PCSK1N...
# Alpha-state 2 down<-10                 CHGA;PCSK1N;LGALS3BP;CRYBA2;CST3;CD99;RPS26;GC...
# Alpha-state 2 down<-5                  CHGA;ATP1A1;PCSK1N;RBP1;GSTM2;RPL3;NUPR1L;CRIP...
# Alpha-state 2 up                       G6PC2;ETFDH;TAF2;SLC38A4;ATP8B1;HADH;BMP5;VPS4...
# Alpha-state 2 up>10                    SLC38A4;THAP5;HIST1H1E;STEAP2;SENP7;TNFSF13B;R...
# Alpha-state 2 up>5                     G6PC2;SLC38A4;VPS41;PDE6B;NECAB1;BHLHE40;MRPL3...
# Alpha-state 3 down                     PCSK1N;GSTM2;FABP5;RPL3;THAP5;CRYBA2;HIST1H1E;...
# Alpha-state 3 down<-10                    RPL21;RPL5;RPS27A;TPT1;EIF1;HSP90AA1;RPL9;JUND
# Alpha-state 3 down<-5                  RPL3;THAP5;SENP7;EEF1A1;NFKBIZ;RPS26;DNAJA1;FO...
# Alpha-state 3 up                       NPEPL1;G6PC2;CRADD;MS4A8;ETFDH;NEUROD1;SLC38A4...
# Alpha-state 3 up>10                    G6PC2;SLC38A4;C10orf10;RBP4;COX7A2;NGFRAP1;QDP...
# Alpha-state 3 up>5                     G6PC2;ETFDH;NEUROD1;SLC38A4;C10orf10;PSPH;PDCD...
# Alpha-state 4 down                     INS;NPEPL1;G6PC2;DHRS2;IPO13;GPD1L;ETFDH;KCNA5...
# Alpha-state 4 down<-10                 G6PC2;ETFDH;SLC38A4;C10orf10;VPS41;DUSP26;RRM1...
# Alpha-state 4 down<-5                  NPEPL1;G6PC2;IPO13;GPD1L;ETFDH;KCNA5;EHF;NEURO...
# Alpha-state 4 up                       CRADD;MS4A8;TAF2;WWC1;C1orf168;SLC37A3;RBP1;SP...
# Alpha-state 4 up>10                    RPL3;CRYBA2;CD99;EEF1A1;RPS26;GC;FOS;DUSP1;TTR...
# Alpha-state 4 up>5                     CRADD;WWC1;SLC37A3;SPIDR;GSTM2;FABP5;RPL3;C11o...
# Alpha-state 5 down                     INS;NPEPL1;KCNK17;KCNK16;FAM159B;CHGA;C1orf168...
# Alpha-state 5 down<-10                 INS;PCSK1N;RPL3;CRIP2;LGALS3BP;CRYBA2;CST3;CD9...
# Alpha-state 5 down<-5                  INS;KCNK17;KCNK16;FAM159B;CHGA;YTHDC1;PCSK1N;R...
# Alpha-state 5 up                       IPO13;GPD1L;KCNA5;RSAD2;NEUROD1;ATP1A1;SSTR1;S...
# Alpha-state 5 up>10                    CLDND1;PTP4A1;TMED8;TGOLN2;YWHAQ;STRAP;DDX39B;...
# Alpha-state 5 up>5                     KCNA5;NEUROD1;SSTR1;VPS41;LDB2;FABP5;PROSER1;R...
# ...                                                                                  ...
# Alpha1                                 DHRS2;ETFDH;MYBPHL;KCNA5;ARHGEF40;TMEM130;CCDC...
# Alpha2                                 ATP1A1;VPS41;BHLHE40;CTNND2;LPAR6;TTBK1;FER;MR...
# Beta sub1_xin                          PRSS23;SCGB2A1;FFAR4;RBP4;PPP1R1A;SCGN;ASCL2;T...
# Beta sub2_xin                          ID1;RBP1;RGS16;GPX3;FOS;NPY;RASD1;JUNB;ID3;NEN...
# Beta sub3_xin                                      INS;CHGA;ASB9;DLK1;CPE;TIMP1;CKB;CHGB
# Beta sub4_xin                          DNAJB9;ID2;COPZ1;BRIX1;HSPD1;HSPE1;SAP18;MRPL1...
# Beta-state1 genesdown                  G6PC2;ETFDH;TFDP1;RRM1;RPL3;MMRN1;DNAJB9;SMAD9...
# Beta-state1 genesdown<-5               DNAJB9;EIF4A2;PCSK1;EEF1A1;CCNC;RPS26;TVP23B;H...
# Beta-state1 genesup                    INS;NPEPL1;DHRS2;ID1;IPO13;KCNK17;GPD1L;KLHDC4...
# Beta-state1 genesup>5                  INS;DHRS2;ID1;KLHDC4;CRADD;KCNK16;FAM159B;ABLI...
# Beta-state2 genesdown                  CASR;IPO13;KLHDC4;ENTPD3;FAM159B;CHGA;C10orf10...
# Beta-state2 genesdown<-5               ENTPD3;CHGA;C10orf10;ATP1A1;PCSK1N;DUSP26;DNAJ...
# Beta-state2 genesup                    ETFDH;SLC25A34;BMP5;VPS41;PDE6B;NECAB1;BHLHE40...
# Beta-state2 genesup>5                  BMP5;PDE6B;PDCD10;THAP5;SMAD9;GPX2;PARVB;MSI1;...
# Beta-state3 genesdown                  CASR;G6PC2;DHRS2;ID1;GPD1L;KCNK16;ETFDH;TAF2;N...
# Beta-state3 genesdown<-5               CASR;G6PC2;DHRS2;KCNK16;ETFDH;NEUROD1;SLC25A34...
# Beta-state3 genesup                    IPO13;KCNA5;SCTR;PRKAB1;DUSP26;DPY19L2;RPL3;KL...
# Beta-state3 genesup>5                  RPL3;ASB9;CST3;DLK1;CD99;EEF1A1;TPPP3;TNFSF13B...
# Beta-state4 genesdown                  INS;ID1;FAM159B;SAMD11;YTHDC1;PCSK1N;RBP1;GSTM...
# Beta-state4 genesdown<-5               INS;FAM159B;SAMD11;YTHDC1;PCSK1N;RBP1;RPL3;CRI...
# Beta-state4 genesup                    CASR;G6PC2;DHRS2;IPO13;ENTPD3;KCNA5;NEUROD1;SL...
# Beta-state4 genesup>5                  CASR;G6PC2;IPO13;ENTPD3;KCNA5;NEUROD1;SLC38A4;...
# Beta1                                  INS-IGF2;INS;CASR;NPEPL1;G6PC2;DHRS2;ID1;XIRP2...
# Beta2                                  PTPRN;SERTAD4;SIN3A;PRPSAP1;TYRO3;WDR1;RAB40C;...
# ND_exocytosis_anticorrelated           PSPH;TFDP1;PDCD10;ID2;C14orf166;PCGF3;NDUFS2;A...
# ND_exocytosis_anticorrelated_filtered  PSPH;TFDP1;PDCD10;ID2;C14orf166;PCGF3;NDUFS2;A...
# ND_exocytosis_correlated               INS;FAM159B;SLC37A3;BMP5;RBP1;KCNH2;TCF20;HERC...
# ND_exocytosis_correlated_filtered      INS;FAM159B;BMP5;RBP1;KCNH2;HERC2;GPX3;GSTK1;T...
# multi_correlated                       FAM159B;CHGA;BMP5;KCNH2;GPX3;GSTK1;DMKN;MRAP2;...
# mutli_anticorrelated                   ID2;RBP4;H1F0;MAGEH1;SNF8;SLC25A6;PSMB7;STK25;...
#
#                                                                              ledge_genes
# Term
# Alpha-state 1 down                     TBPL1;TMEM167B;AGPAT5;ATRN;ZNF781;DNAJC25;TMEM...
# Alpha-state 1 down<-10                 TMEM66;HSP90AA1;RPL9;H3F3A;HNRNPA1;TMEM59;FOSB...
# Alpha-state 1 down<-5                  C22orf39;TCAIM;EIF1AX;RPL7;GCH1;FH;SUB1;PAK2;P...
# Alpha-state 1 up                       MRPS28;CINP;RPL37;SLC27A1;HMBS;PIGV;UBAC1;PYGB...
# Alpha-state 1 up>10                    GSK3A;MZF1;IFI27L1;B3GNT1;CDK4;MRPL28;RBM42;C1...
# Alpha-state 1 up>5                     HMBS;PIGV;UBAC1;PYGB;GSK3A;ADCY6;SEPW1;SLC50A1...
# Alpha-state 2 down                     C17orf70;ATP5D;RAB7A;NT5C;ACADS;TUBGCP2;ZNF511...
# Alpha-state 2 down<-10                 RPS7;TMEM160;CFL1;ATP6AP1;PSAP;RAB1B;TUBB4B;CL...
# Alpha-state 2 down<-5                  CDK4;MRPL28;RBM42;C19orf70;RPS16;SUPT5H;C19orf...
# Alpha-state 2 up                       PPIL4;COX18;TNPO2;PRKAA2;EIF2S3;WSB1;TAX1BP1;C...
# Alpha-state 2 up>10                    RAD23B;RBM6;ITCH;RBM26;EIF2S3;WSB1;CHP1;SCD;MA...
# Alpha-state 2 up>5                     RAD23B;CRYZ;TYW3;RBM6;COPB1;CDC42;STXBP3;ITCH;...
# Alpha-state 3 down                     PTBP1;SYN1;RPL7;RPL12;SNRNP70;LRP6;ARID5B;YME1...
# Alpha-state 3 down<-10                                      TPT1;EIF1;HSP90AA1;RPL9;JUND
# Alpha-state 3 down<-5                  PTP4A2;PRRC2C;EIF1;C12orf75;TNKS2;BROX;HSPA1B;...
# Alpha-state 3 up                       TCF25;SGSM3;RPE;SPRYD3;IMP4;CCDC115;NDUFC2;RPA...
# Alpha-state 3 up>10                                               G6PC2;SLC38A4;C10orf10
# Alpha-state 3 up>5                     MPV17;SIAE;WSB1;CCNDBP1;P2RX4;CLIC1;NDUFAB1;NO...
# Alpha-state 4 down                     ZER1;UGCG;FAM160B1;SRRM2;SCP2;VARS;ANKS3;AP5S1...
# Alpha-state 4 down<-10                 GIGYF1;BAG1;DNAJC10;CAPN1;PRDX5;PSENEN;FOXRED2...
# Alpha-state 4 down<-5                  ZER1;UGCG;FAM160B1;SRRM2;VARS;ANKS3;AP5S1;RAB8...
# Alpha-state 4 up                       FKBP1A;VRK2;RSF1;DEF8;AVL9;FKBP15;BRPF3;BLOC1S...
# Alpha-state 4 up>10                    DNAJB1;H3F3B;CALM1;PPIA;EIF1;C12orf75;HSPA1B;H...
# Alpha-state 4 up>5                     ALYREF;VPS25;BMPR2;PM20D2;MKRN1;PARP6;INADL;TR...
# Alpha-state 5 down                     RPL8;BSG;PRDX5;TRMT112;COX4I1;RPL18A;C19orf53;...
# Alpha-state 5 down<-10                 TIMP1;HSD17B14;RPL37;SEPW1;C19orf70;RPS16;CKB;...
# Alpha-state 5 down<-5                  RPL8;BSG;PRDX5;TRMT112;COX4I1;RPL18A;C19orf53;...
# Alpha-state 5 up                       HUWE1;FAM21A;RNF214;ACTR3;UNC50;STAG1;RBM22;DN...
# Alpha-state 5 up>10                    KCTD12;DAG1;MRFAP1;INA;TUBB;DDX5;CSE1L;PRNP;AR...
# Alpha-state 5 up>5                     TRIM25;SLC25A3;PBRM1;EFCAB14;SLC25A44;BTAF1;C1...
# ...                                                                                  ...
# Alpha1                                 DHRS2;ETFDH;MYBPHL;KCNA5;ARHGEF40;TMEM130;CCDC...
# Alpha2                                 PACS2;BRF1;RPL19;ZNF592;BUB1;TWISTNB;TIPRL;NEK...
# Beta sub1_xin                                                        NPTX2;TUBB2A;TUBA4A
# Beta sub2_xin                                                             ID1;RBP1;RGS16
# Beta sub3_xin                                                         INS;CHGA;ASB9;DLK1
# Beta sub4_xin                          BTG1;NEU1;ACTR3;SERINC2;PPIB;SHMT2;DDIT4;PPIG;...
# Beta-state1 genesdown                  TRAM1;C12orf23;ATP6V1G1;WBP4;GTF2E2;RPL7;KIAA1...
# Beta-state1 genesdown<-5               H3F3B;MDH1;OSTC;TTC3;ANKRD36;ARF4;PPIA;EIF4E;E...
# Beta-state1 genesup                    MRPS28;CINP;RPL37;PIGV;UBAC1;PYGB;EP400;LRRC20...
# Beta-state1 genesup>5                  GSK3A;MZF1;GCDH;PHKG2;B3GNT1;CDK4;MRPL28;CLN3;...
# Beta-state2 genesdown                  ATXN10;RNF138;PPIB;MRPL4;DUS3L;BAD;SPNS1;MCUR1...
# Beta-state2 genesdown<-5               ATP5D;NT5C;TUBGCP2;RNF40;TAGLN2;CNIH2;XPR1;BAG...
# Beta-state2 genesup                    RBM26;NIPAL3;NAA38;PPIL4;TNPO2;EIF2S3;WSB1;TAX...
# Beta-state2 genesup>5                  RAD23B;CRYZ;RBM6;CDC42;ITCH;UQCC2;RBM26;NIPAL3...
# Beta-state3 genesdown                  ZNF236;ARHGEF18;DAXX;GOPC;CCDC88C;DCTN1;ASNS;S...
# Beta-state3 genesdown<-5               EIF2S3;MPV17;WSB1;COX20;CHP1;SCD;BCL2L13;MYCBP...
# Beta-state3 genesup                    NDUFAF1;U2AF1;RBMX2;SERINC1;PPP1CA;MIS18BP1;ZE...
# Beta-state3 genesup>5                  DNAJB11;EPCAM;ARF4;RPS5;PPIA;EIF1;ERP44;ABCA3;...
# Beta-state4 genesdown                  RPL8;BSG;PRDX5;TRMT112;COX4I1;RPL18A;C19orf53;...
# Beta-state4 genesdown<-5               NHP2L1;CNIH2;GIGYF1;RPL8;BSG;PRDX5;TRMT112;COX...
# Beta-state4 genesup                    TMEM30B;TCTN3;ZNF791;DDHD2;HUWE1;FAM21A;BTG1;N...
# Beta-state4 genesup>5                  GDI2;GOLT1B;PRKACB;ZFAND3;XBP1;AP5M1;EXOC5;ACT...
# Beta1                                  INS-IGF2;INS;CASR;NPEPL1;G6PC2;DHRS2;ID1;XIRP2...
# Beta2                                  PTPRN;SERTAD4;SIN3A;PRPSAP1;TYRO3;WDR1;RAB40C;...
# ND_exocytosis_anticorrelated           ALG2;SAT1;MIEF1;RAB21;HNRNPH3;RSF1;ME1;GSTO1;P...
# ND_exocytosis_anticorrelated_filtered  ALG2;SAT1;RAB21;HNRNPH3;RSF1;ME1;GSTO1;POP7;ZN...
# ND_exocytosis_correlated               SLC37A1;PIGP;ZBTB7A;GGCX;AAED1;PSMB8;DNAJC5;YP...
# ND_exocytosis_correlated_filtered      NDFIP2;GSTA4;C1QL1;ABCA2;SIK2;PPIL4;QARS;RFK;T...
# multi_correlated                                                 FAM159B;CHGA;BMP5;KCNH2
# mutli_anticorrelated                   SRXN1;HGS;TBCC;SNRPB;UGDH;SIGMAR1;DNTTIP2;ANP3...
#
# [66 rows x 8 columns]

# %%
gs_res_a.res2d.shape
# Out:
# (66, 8)

# %%
gs_res_a.res2d[(gs_res_a.res2d['pval']<0.01)].shape
# Out:
# (46, 8)

# %%
gs_res_a.res2d[(gs_res_a.res2d['pval']<0.1) & (gs_res_a.res2d['es']>0)]
# Out:
#               es       nes  pval  fdr  geneset_size  matched_size  \
# Term
# Alpha1  1.000000  4.525805   0.0  0.0           179            68
# Beta1   0.818461  4.260141   0.0  0.0           178            87
#
#                                                     genes  \
# Term
# Alpha1  SPAG16;GCG;TTR;TMEM72;SEMA6A;SND1;C1orf168;KCN...
# Beta1   SPAG16;C1orf168;KCNA5;NEUROD1;CERKL;EPHX1;MYBP...
#
#                                               ledge_genes
# Term
# Alpha1  SPAG16;GCG;TTR;TMEM72;SEMA6A;SND1;C1orf168;KCN...
# Beta1   SPAG16;C1orf168;KCNA5;NEUROD1;CERKL;EPHX1;MYBP...

# %%
gs_res.res2d[(gs_res.res2d['pval']<0.1) & (gs_res.res2d['es']>0)]
# Out:
#                      es       nes      pval       fdr  geneset_size  \
# Term
# Alpha1         0.837166  3.758180  0.000000  0.000000           179
# Beta1          1.000000  4.501983  0.000000  0.000000           178
# Beta sub3_xin  0.780771  2.084773  0.000000  0.001461            13
# Beta sub2_xin  0.548305  1.753645  0.022059  0.026297            28
#
#                matched_size  \
# Term
# Alpha1                   68
# Beta1                    89
# Beta sub3_xin             8
# Beta sub2_xin            17
#
#                                                            genes  \
# Term
# Alpha1         DHRS2;ETFDH;MYBPHL;KCNA5;ARHGEF40;TMEM130;CCDC...
# Beta1          INS-IGF2;INS;CASR;NPEPL1;G6PC2;DHRS2;ID1;XIRP2...
# Beta sub3_xin              INS;CHGA;ASB9;DLK1;CPE;TIMP1;CKB;CHGB
# Beta sub2_xin  ID1;RBP1;RGS16;GPX3;FOS;NPY;RASD1;JUNB;ID3;NEN...
#
#                                                      ledge_genes
# Term
# Alpha1         DHRS2;ETFDH;MYBPHL;KCNA5;ARHGEF40;TMEM130;CCDC...
# Beta1          INS-IGF2;INS;CASR;NPEPL1;G6PC2;DHRS2;ID1;XIRP2...
# Beta sub3_xin                                 INS;CHGA;ASB9;DLK1
# Beta sub2_xin                                     ID1;RBP1;RGS16

# %% [markdown]
# ## delta

# %% [markdown]
# gs_res_d=run_GSEA_gene('delta')
# gs_res_d.res2d.sort_index()

# %% [markdown]
# ### Save results

# %%
gs_res.res2d[['es','nes','pval','fdr','geneset_size','matched_size']].to_csv('../dat/figdata/GSEA_beta_all_seed1000_p1000.csv')
gs_res_a.res2d[['es','nes','pval','fdr','geneset_size','matched_size']].to_csv('../dat/figdata/GSEA_alpha_all_seed1000_p1000.csv')
#gs_res_d.res2d[['es','nes','pval','fdr','geneset_size','matched_size']].to_csv('../dat/figdata/GSEA_delta_all_seed1000_p10000.csv')

from gseapy.plot import gseaplot, heatmap
terms = gs_res.res2d.index 
for i in range(len(terms)):
    gseaplot(gs_res.ranking, term=terms[i], **gs_res.results[terms[i]],ofname=terms[i]+'_beta_all_seed1000_p10000.pdf')
terms = gs_res_a.res2d.index 
for i in range(len(terms)):
    gseaplot(gs_res_a.ranking, term=terms[i], **gs_res_a.results[terms[i]],ofname=terms[i]+'_all_seed1000_p10000.pdf')
#terms = gs_res_d.res2d.index 
#for i in range(len(terms)):
#    gseaplot(gs_res_d.ranking, term=terms[i], **gs_res_a.results[terms[i]],ofname=terms[i]+'_delta_all_seed1000_p10000.pdf')
