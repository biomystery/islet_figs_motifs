# %% [markdown]
# # Perform GSEA using GSEAPY
#
# Following the potocol defined here: https://gseapy.readthedocs.io/en/latest/gseapy_tutorial.html#use-gsea-command-or-gsea

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina' # mac
import pandas as pd
import gseapy as gp
import numpy as np
import matplotlib.pyplot as plt

# %%
gp.__version__
# Out:
# '0.9.9'

# %% [markdown]
# ## alpha

# %%
gene_exp_alpha = pd.read_csv("../dat/figdata/fig2_prom_ttest_res.csv",index_col=1)
#gene_exp_alpha.head()
df = gene_exp_alpha.loc[gene_exp_alpha["celltype"]=="alpha"].sort_values(by='odds', ascending=False)["odds"]
df=np.log2(df)

# replace inf to max exclude inf
#df=df.replace(np.inf,df[~df.isin([np.inf])].max(0))
#df=df.replace(-np.inf,df[~df.isin([-np.inf])].min(0))
df.to_csv('../dat/figdata/res.genes.a.rnk',sep='\t')
rnk = pd.read_table("../dat/figdata/res.genes.a.rnk", header=None)

for i in  rnk.index[(rnk[1]==np.inf).tolist()].tolist():
    rnk.iloc[i,1]= df[~df.isin([np.inf])].max(0)*(1+np.random.uniform()/100)

for i in  rnk.index[(rnk[1]==-np.inf).tolist()].tolist():
    rnk.iloc[i,1]= df[~df.isin([-np.inf])].min(0)*(1+np.random.uniform()/100)

#rnk.set_index(0)
#rnk.head()

# run gsea
# enrichr libraries are supported by gsea module. Just provide the name

gs_res_a = gp.prerank(rnk=rnk, # or data='./P53_resampling_data.txt'
                 gene_sets='../dat/glists/gsea.gmt', # enrichr library names or gmt file
                 #set permutation_type to phenotype if samples >=15
                 permutation_num=1000, # reduce number to speed up test
                 outdir=None,  # do not write output to disk
                 no_plot=True, # Skip plotting
                 #weighted_score_type=1,
                 #ascending=False,
                    seed=1000,
                 min_size=1,
                 max_size=2100,
                 processes=4)
                 #format='png')
gs_res_a.res2d
# Out:
# /Users/frank/anaconda/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log2
#   after removing the cwd from sys.path.
# /Users/frank/anaconda/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:9: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   if __name__ == '__main__':
# /Users/frank/anaconda/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:10: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   # Remove the CWD from sys.path while we load stuff.
# 2019-03-12 15:18:20,835 Input gene rankings contains duplicated IDs, Only use the duplicated ID with highest value!
#                         es       nes      pval       fdr  geneset_size  \
# Term
# CD9-_dorrell      0.567534  1.780571  0.001366  0.005885            57
# ST8SIA1+_dorrell  0.593715  1.856076  0.001362  0.006420            46
# Beta sub4_xin    -0.308176 -1.636402  0.000000  0.035672           390
# ST8SIA1-_dorrell  0.423652  1.399479  0.054430  0.169052            65
# immature_bader   -0.184281 -1.009991  0.461538  0.434800           579
# mature_bader      0.347465  1.107615  0.335142  0.610673            72
# Beta sub3_xin     0.398034  0.864542  0.610018  0.700548            13
# Beta sub1_xin     0.373673  0.892001  0.569052  0.754619            13
# Beta sub2_xin     0.323691  0.931182  0.541159  0.793723            28
# CD9+_dorrell      0.311231  0.952579  0.553521  0.895760            45
#
#                   matched_size  \
# Term
# CD9-_dorrell                55
# ST8SIA1+_dorrell            45
# Beta sub4_xin              386
# ST8SIA1-_dorrell            64
# immature_bader             563
# mature_bader                51
# Beta sub3_xin                9
# Beta sub1_xin               13
# Beta sub2_xin               28
# CD9+_dorrell                41
#
#                                                               genes  \
# Term
# CD9-_dorrell      CCDC81;HDAC9;SEMA6A;PTPN13;CNKSR2;IGSF1;RALYL;...
# ST8SIA1+_dorrell  SCN3A;SULF2;SH3KBP1;CORO2B;TMEM130;TP53I11;OPC...
# Beta sub4_xin     C12orf29;C1orf43;PSMF1;GDF15;ARG2;GCG;MMP7;SNX...
# ST8SIA1-_dorrell  SLC5A1;RYK;AFAP1;RALGPS2;G6PC2;DISP1;SCGB2A1;N...
# immature_bader    SLC7A8;PSMB7;STT3A;LANCL1;MBTPS1;PSMF1;TM2D3;A...
# mature_bader      PAWR;PSTPIP1;NOSTRIN;TNS1;SVEP1;RHOH;NHSL1;WNT...
# Beta sub3_xin         IGFBP7;CHGA;ASB9;LAMP1;CPE;INS;TIMP1;CKB;CHGB
# Beta sub1_xin     FXYD2;RBP4;PPP1R1A;SCGB2A1;FFAR4;SCGN;PRSS23;T...
# Beta sub2_xin     PCP4;TFF3;PEMT;NPY;IAPP;RBP1;AP3B1;RPS4X;PAM;G...
# CD9+_dorrell      AKAP13;GNAL;TSPAN33;KCNA5;AK5;RBP4;PPP1R1A;RAI...
#
#                                                         ledge_genes
# Term
# CD9-_dorrell      CCDC81;HDAC9;SEMA6A;PTPN13;CNKSR2;IGSF1;RALYL;...
# ST8SIA1+_dorrell  SCN3A;SULF2;SH3KBP1;CORO2B;TMEM130;TP53I11;OPC...
# Beta sub4_xin     RPS19;SYF2;SRSF7;MANF;RAD23B;ARF4;RPS27L;DDIT4...
# ST8SIA1-_dorrell  SLC5A1;RYK;AFAP1;RALGPS2;G6PC2;DISP1;SCGB2A1;N...
# immature_bader    MAPK3;PPIB;SNUPN;MED27;POLD2;CCNL2;PPA2;ASNA1;...
# mature_bader      PAWR;PSTPIP1;NOSTRIN;TNS1;SVEP1;RHOH;NHSL1;WNT...
# Beta sub3_xin                                           IGFBP7;CHGA
# Beta sub1_xin                 FXYD2;RBP4;PPP1R1A;SCGB2A1;FFAR4;SCGN
# Beta sub2_xin                               PCP4;TFF3;PEMT;NPY;IAPP
# CD9+_dorrell      AKAP13;GNAL;TSPAN33;KCNA5;AK5;RBP4;PPP1R1A;RAI...

# %% [markdown]
# ## beta

# %%
gene_exp_alpha = pd.read_csv("../dat/figdata/fig2_prom_ttest_res.csv",index_col=1)
#gene_exp_alpha.head()
df = gene_exp_alpha.loc[gene_exp_alpha["celltype"]=="beta"].sort_values(by='odds', ascending=False)["odds"]
df=np.log2(df)

# replace inf to max exclude inf
#df=df.replace(np.inf,df[~df.isin([np.inf])].max(0))
#df=df.replace(-np.inf,df[~df.isin([-np.inf])].min(0))
df.to_csv('../dat/figdata/res.genes.a.rnk',sep='\t')
rnk = pd.read_table("../dat/figdata/res.genes.a.rnk", header=None)

for i in  rnk.index[(rnk[1]==np.inf).tolist()].tolist():
    rnk.iloc[i,1]= df[~df.isin([np.inf])].max(0)*(1+np.random.uniform()/100)

for i in  rnk.index[(rnk[1]==-np.inf).tolist()].tolist():
    rnk.iloc[i,1]= df[~df.isin([-np.inf])].min(0)*(1+np.random.uniform()/100)

#rnk.set_index(0)
#rnk.head()


# run gsea
# enrichr libraries are supported by gsea module. Just provide the name

gs_res = gp.prerank(rnk=rnk, # or data='./P53_resampling_data.txt'
                 gene_sets='../dat/glists/gsea.gmt', # enrichr library names or gmt file
                 #set permutation_type to phenotype if samples >=15
                 permutation_num=1000, # reduce number to speed up test
                 outdir=None,  # do not write output to disk
                 no_plot=True, # Skip plotting
                 #weighted_score_type=1,
                 #ascending=False,
                    seed=1000,
                 min_size=10,
                 max_size=2100,
                 processes=8)
                 #format='png')
gs_res.res2d
# Out:
# 2019-03-12 15:18:28,150 Input gene rankings contains duplicated IDs, Only use the duplicated ID with highest value!
#                         es       nes      pval       fdr  geneset_size  \
# Term
# Beta sub4_xin    -0.340284 -1.963376  0.000000  0.000611           390
# ST8SIA1+_dorrell  0.562926  1.651712  0.007034  0.051650            46
# Beta sub2_xin     0.569174  1.533191  0.026350  0.052726            28
# CD9-_dorrell      0.507622  1.540481  0.015312  0.074247            57
# Beta sub3_xin     0.643224  1.421294  0.090370  0.102762            13
# ST8SIA1-_dorrell  0.442361  1.358038  0.071982  0.133429            65
# mature_bader      0.429090  1.263578  0.161939  0.200681            72
# CD9+_dorrell      0.345443  0.989489  0.494636  0.654540            45
# Beta sub1_xin     0.359062  0.826429  0.700468  0.864329            13
# immature_bader    0.185730  0.642788  1.000000  0.940340           579
#
#                   matched_size  \
# Term
# Beta sub4_xin              385
# ST8SIA1+_dorrell            46
# Beta sub2_xin               27
# CD9-_dorrell                56
# Beta sub3_xin               10
# ST8SIA1-_dorrell            65
# mature_bader                50
# CD9+_dorrell                42
# Beta sub1_xin               13
# immature_bader             565
#
#                                                               genes  \
# Term
# Beta sub4_xin     PSMF1;WDR45B;HSPA9;ANXA2;ATP6V0D1;KRT8;ATP6V1H...
# ST8SIA1+_dorrell  C1orf127;CORO2B;TMEM130;MYOM1;TP53I11;SULF2;SH...
# Beta sub2_xin     PCP4;PEMT;AP3B1;ID1;STMN2;RBP1;TFF3;GNAS;IAPP;...
# CD9-_dorrell      SPARCL1;CCDC81;ASB9;KCNMB2;PTPRD;SEMA6A;ITM2A;...
# Beta sub3_xin     INS;ASB9;DLK1;CHGA;LAMP1;IGFBP7;CPE;CKB;TIMP1;...
# ST8SIA1-_dorrell  GPD1L;SLC39A11;TCEA3;RYK;AFAP1;FRMD4B;G6PC2;RR...
# mature_bader      KIF6;NEB;TNS1;SYNGAP1;CX3CR1;NOSTRIN;CAV1;NPFF...
# CD9+_dorrell      TSPAN33;KCNA5;COL6A2;GNAL;SEL1L3;AKAP13;TACSTD...
# Beta sub1_xin     PRSS23;FXYD2;SCGB2A1;FFAR4;RBP4;PPP1R1A;SCGN;A...
# immature_bader    NELL1;TMEM63A;PARVA;PGM1;ATP2A3;APBB3;C1orf127...
#
#                                                         ledge_genes
# Term
# Beta sub4_xin     ARID5B;EIF2S2;ZFAND2A;ARPP19;XBP1;TMEM258;U2AF...
# ST8SIA1+_dorrell  C1orf127;CORO2B;TMEM130;MYOM1;TP53I11;SULF2;SH...
# Beta sub2_xin     PCP4;PEMT;AP3B1;ID1;STMN2;RBP1;TFF3;GNAS;IAPP;...
# CD9-_dorrell      SPARCL1;CCDC81;ASB9;KCNMB2;PTPRD;SEMA6A;ITM2A;...
# Beta sub3_xin                       INS;ASB9;DLK1;CHGA;LAMP1;IGFBP7
# ST8SIA1-_dorrell  GPD1L;SLC39A11;TCEA3;RYK;AFAP1;FRMD4B;G6PC2;RR...
# mature_bader      KIF6;NEB;TNS1;SYNGAP1;CX3CR1;NOSTRIN;CAV1;NPFF...
# CD9+_dorrell      TSPAN33;KCNA5;COL6A2;GNAL;SEL1L3;AKAP13;TACSTD...
# Beta sub1_xin                       PRSS23;FXYD2;SCGB2A1;FFAR4;RBP4
# immature_bader    NELL1;TMEM63A;PARVA;PGM1;ATP2A3;APBB3;C1orf127...

# %% [markdown]
# ### Save results

# %%
gs_res.res2d[['es','nes','pval','fdr']].to_csv('../dat/figdata/GSEA_beta_Xin_seed1000.csv')
gs_res_a.res2d[['es','nes','pval','fdr']].to_csv('../dat/figdata/GSEA_alpha_Xin_seed1000.csv')

from gseapy.plot import gseaplot, heatmap
terms = gs_res.res2d.index 
for i in range(len(terms)):
    gseaplot(gs_res.ranking, term=terms[i], **gs_res.results[terms[i]],ofname=terms[i]+'_xin_b_seed1000.pdf')
terms = gs_res_a.res2d.index 
for i in range(len(terms)):
    gseaplot(gs_res_a.ranking, term=terms[i], **gs_res_a.results[terms[i]],ofname=terms[i]+'_xin_a_seed1000.pdf')
