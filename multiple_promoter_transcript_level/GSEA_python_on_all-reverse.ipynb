# %% [markdown]
# # Perform GSEA using GSEAPY
#
# Following the potocol defined here: https://gseapy.readthedocs.io/en/latest/gseapy_tutorial.html#use-gsea-command-or-gsea

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina' # mac
import pandas as pd
import gseapy as gp
import numpy as np
import matplotlib.pyplot as plt

# %%
gp.__version__
# Out:
# '0.9.9'

# %%
def run_GSEA_gene(celltype='alpha',
             rnkfile="../dat/figdata/fig2_prom_ttest_res_genelevel.csv",
             glist='../dat/glists/gsea_all.gmt'):
    gene_exp_alpha = pd.read_csv(rnkfile,index_col=1)
    #gene_exp_alpha.head()
    rnk = gene_exp_alpha.loc[(gene_exp_alpha["celltype"]==celltype) & (~gene_exp_alpha["isAmbious"])].sort_values(by='mlog10P')["mlog10P"]
    rnk = -rnk
    print(rnk.shape)
    print(rnk.head(1))
    print(rnk.tail(1))

    gs_res_a = gp.prerank(rnk=rnk, # or data='./P53_resampling_data.txt'
                     gene_sets=glist, # enrichr library names or gmt file
                     #set permutation_type to phenotype if samples >=15
                     permutation_num=10000, # reduce number to speed up test
                     outdir=None,  # do not write output to disk
                     no_plot=True, # Skip plotting
                     #weighted_score_type=1,
                     #ascending=False,
                        seed=1000,
                     min_size=1,
                     max_size=5000,
                     processes=8)
                     #format='png')
    return(gs_res_a)

# %% [markdown]
# ## alpha

# %%
gs_res_a=run_GSEA_gene('alpha')
gs_res_a.res2d.sort_index()
# Out:
# (13130,)
# gene
# FOSL1    34.795613
# Name: mlog10P, dtype: float64
# gene
# SPAG16   -24.642316
# Name: mlog10P, dtype: float64
#                                              es       nes      pval       fdr  \
# Term
# Alpha-state 1 down                     0.448197  1.246213  0.000000  0.041030
# Alpha-state 1 up                       0.466623  1.302560  0.000000  0.033445
# Alpha-state 2 down                     0.478090  1.327160  0.000000  0.032727
# Alpha-state 2 up                       0.423301  1.177005  0.000000  0.061568
# Alpha-state 3 down                     0.545584  1.499354  0.000000  0.014877
# Alpha-state 3 up                       0.375801  1.042652  0.166600  0.270467
# Alpha-state 4 down                     0.480650  1.342669  0.000000  0.043459
# Alpha-state 4 up                       0.462909  1.287551  0.000000  0.031964
# Alpha-state 5 down                     0.422793  1.169002  0.000100  0.064035
# Alpha-state 5 up                       0.481419  1.336061  0.000000  0.040637
# Alpha-state 6 down                     0.412245  1.148884  0.000000  0.075382
# Alpha-state 6 up                       0.509542  1.409560  0.000000  0.024254
# Alpha1                                -1.000000 -4.860882  0.000000  0.000000
# Alpha2                                 0.906829  2.475300  0.000000  0.000000
# Beta sub1_xin                          0.562089  1.203701  0.222676  0.051993
# Beta sub2_xin                          0.365772  0.848129  0.739445  0.966863
# Beta sub3_xin                          0.488291  0.915949  0.617308  0.928183
# Beta sub4_xin                          0.529747  1.443565  0.000000  0.018901
# Beta-state1 genesdown                  0.477095  1.317174  0.000000  0.033528
# Beta-state1 genesup                    0.466299  1.299719  0.000000  0.030177
# Beta-state2 genesdown                  0.480018  1.332242  0.000000  0.033854
# Beta-state2 genesup                    0.447750  1.239668  0.000000  0.041715
# Beta-state3 genesdown                  0.455028  1.270005  0.000000  0.034286
# Beta-state3 genesup                    0.476179  1.316006  0.000000  0.031389
# Beta-state4 genesdown                  0.440830  1.217489  0.000000  0.047533
# Beta-state4 genesup                    0.460854  1.282003  0.000000  0.032053
# Beta1                                 -0.818461 -3.819376  0.000000  0.000000
# Beta2                                  0.741240  2.032695  0.000000  0.000000
# ND_exocytosis_anticorrelated           0.483485  1.301546  0.000800  0.031565
# ND_exocytosis_anticorrelated_filtered  0.500077  1.335726  0.000400  0.036270
# ND_exocytosis_correlated               0.437761  1.179516  0.028700  0.062524
# ND_exocytosis_correlated_filtered      0.463076  1.227368  0.030106  0.044960
# T2D_exocytosis_anticorrelated          0.395836  1.078455  0.159800  0.158444
# T2D_exocytosis_correlated              0.329494  0.838575  0.816677  0.943318
# multi_correlated                       0.445434  1.107598  0.306512  0.113555
# mutli_anticorrelated                   0.579211  1.457088  0.003834  0.020074
#
#                                        geneset_size  matched_size  \
# Term
# Alpha-state 1 down                             2423          1961
# Alpha-state 1 up                               4578          3696
# Alpha-state 2 down                             1781          1434
# Alpha-state 2 up                               2262          1832
# Alpha-state 3 down                              821           616
# Alpha-state 3 up                               1533          1286
# Alpha-state 4 down                             5779          4727
# Alpha-state 4 up                               2535          2021
# Alpha-state 5 down                             1110           900
# Alpha-state 5 up                               1842          1470
# Alpha-state 6 down                             3302          2731
# Alpha-state 6 up                               1337          1016
# Alpha1                                          179            68
# Alpha2                                          500           390
# Beta sub1_xin                                    13            12
# Beta sub2_xin                                    28            21
# Beta sub3_xin                                    13             6
# Beta sub4_xin                                   390           351
# Beta-state1 genesdown                           981           799
# Beta-state1 genesup                            3385          2738
# Beta-state2 genesdown                          1784          1433
# Beta-state2 genesup                            1397          1103
# Beta-state3 genesdown                          4369          3499
# Beta-state3 genesup                            1126           939
# Beta-state4 genesdown                           989           814
# Beta-state4 genesup                            2354          1904
# Beta1                                           178            87
# Beta2                                           682           499
# ND_exocytosis_anticorrelated                    250           197
# ND_exocytosis_anticorrelated_filtered           191           151
# ND_exocytosis_correlated                        311           224
# ND_exocytosis_correlated_filtered               182           130
# T2D_exocytosis_anticorrelated                   449           365
# T2D_exocytosis_correlated                        77            56
# multi_correlated                                 57            41
# mutli_anticorrelated                             54            46
#
#                                                                                    genes  \
# Term
# Alpha-state 1 down                     CREB5;GADD45B;TOR1AIP1;MGA;ATF3;PRPSAP1;CNOT7;...
# Alpha-state 1 up                       MARCKSL1;SPTAN1;HMGA1;HNRNPAB;EZH1;ABCB9;MAP7D...
# Alpha-state 2 down                     GADD45B;HMGA1;HNRNPAB;ABHD2;TNFRSF12A;NOP56;DE...
# Alpha-state 2 up                       MGA;FOSL2;CLGN;POLR3E;ZNF652;PDS5A;ANKIB1;HP1B...
# Alpha-state 3 down                     MARCKSL1;CREB5;HMGA1;TOR1AIP1;ATF3;ABHD2;YBX1;...
# Alpha-state 3 up                       PRPSAP1;GNPTG;PTPRN;GABARAP;WDR18;TRAPPC6A;P4H...
# Alpha-state 4 down                     HMGA1;MGA;HNRNPAB;ABHD2;PRPSAP1;VPS37A;MAP7D1;...
# Alpha-state 4 up                       FOSL1;MARCKSL1;CREB5;GADD45B;SPTAN1;ATF3;EZH1;...
# Alpha-state 5 down                     TNFRSF12A;TRIM28;FOSB;GNPTG;TSR3;PTPRN;GABARAP...
# Alpha-state 5 up                       MGA;CNOT7;VPS37A;PHLPP2;RUNDC1;PDS5A;HP1BP3;NF...
# Alpha-state 6 down                     MGA;HNRNPAB;EZH1;PRPSAP1;MAP7D1;NOP56;POLR3E;T...
# Alpha-state 6 up                       CREB5;GADD45B;HMGA1;TOR1AIP1;ABHD2;SPHK1;TNFRS...
# Alpha1                                 SLC25A34;PYROXD2;REC8;ISM1;SYT10;C20orf196;DLG...
# Alpha2                                 FOSL1;MARCKSL1;MGA;ATF3;SH2D5;TAF5;ABHD2;CNOT7...
# Beta sub1_xin                          TUBB2A;TUBA4A;NPTX2;TMED6;TAGLN2;ASCL2;PRSS23;...
# Beta sub2_xin                          RPL6;FOS;JUNB;CDKN1C;RASD1;BTG2;RGS16;MLLT11;I...
# Beta sub3_xin                                                CKB;CHGB;CPE;TIMP1;INS;CHGA
# Beta sub4_xin                          GADD45B;TNFRSF12A;CLGN;SRSF2;NXT1;PSMA3;NUDC;P...
# Beta-state1 genesdown                  ATF3;CNOT7;CLGN;RUNDC1;SFMBT1;TLK1;FOSB;DDX42;...
# Beta-state1 genesup                    SPTAN1;HMGA1;HNRNPAB;EZH1;PRPSAP1;MAP7D1;NOP56...
# Beta-state2 genesdown                  GADD45B;HMGA1;TOR1AIP1;HNRNPAB;ABHD2;PRPSAP1;T...
# Beta-state2 genesup                    MGA;ZNF652;ANKIB1;SLC41A2;TLK1;PSMA1;GABARAP;S...
# Beta-state3 genesdown                  SPTAN1;MGA;HNRNPAB;EZH1;PRPSAP1;VPS37A;MAP7D1;...
# Beta-state3 genesup                    GADD45B;STAG3;SFMBT1;FOSB;PSMA3;NUDC;RPLP0;IDE...
# Beta-state4 genesdown                  POLR3E;TLK1;GNPTG;PTPRN;PSMA1;GABARAP;RPLP0;PP...
# Beta-state4 genesup                    TOR1AIP1;MGA;ATF3;ABHD2;PRPSAP1;CNOT7;VPS37A;C...
# Beta1                                  B3GNT5;STX1A;PSD4;SAMD11;PLXND1;KLHL2;FUT9;COR...
# Beta2                                  FOSL1;CREB5;ALOXE3;ANKRD30BL;HMGA1;TOR1AIP1;MG...
# ND_exocytosis_anticorrelated           NUDC;PPP1R15A;CNPPD1;DHPS;XRCC6;SESN2;RAB10;SL...
# ND_exocytosis_anticorrelated_filtered  NUDC;PPP1R15A;CNPPD1;DHPS;XRCC6;RAB10;SLBP;ANX...
# ND_exocytosis_correlated               MGA;ANKIB1;GPRIN1;SMARCC1;KARS;CDKN2C;SERTAD1;...
# ND_exocytosis_correlated_filtered      MGA;GPRIN1;KARS;MEST;TMEM259;MAVS;MAP1LC3A;MXR...
# T2D_exocytosis_anticorrelated          DEK;DEDD2;DNAJB1;SPG20;SMARCB1;UBE2I;FAHD1;ACT...
# T2D_exocytosis_correlated              SSH2;WDR37;CYB5D2;PIK3C2A;KMT2A;SOS1;ZCCHC2;PD...
# multi_correlated                       BIRC2;GPRIN1;RAI1;NPTX2;TRIP12;CACNA1C;SIN3A;M...
# mutli_anticorrelated                   DHPS;COQ6;SRXN1;NOL7;SLC3A2;RSF1;HGS;ANP32B;UG...
#
#                                                                              ledge_genes
# Term
# Alpha-state 1 down                     CREB5;GADD45B;TOR1AIP1;MGA;ATF3;PRPSAP1;CNOT7;...
# Alpha-state 1 up                       MARCKSL1;SPTAN1;HMGA1;HNRNPAB;EZH1;ABCB9;MAP7D...
# Alpha-state 2 down                     GADD45B;HMGA1;HNRNPAB;ABHD2;TNFRSF12A;NOP56;DE...
# Alpha-state 2 up                       MGA;FOSL2;CLGN;POLR3E;ZNF652;PDS5A;ANKIB1;HP1B...
# Alpha-state 3 down                     MARCKSL1;CREB5;HMGA1;TOR1AIP1;ATF3;ABHD2;YBX1;...
# Alpha-state 3 up                       PRPSAP1;GNPTG;PTPRN;GABARAP;WDR18;TRAPPC6A;P4H...
# Alpha-state 4 down                     HMGA1;MGA;HNRNPAB;ABHD2;PRPSAP1;VPS37A;MAP7D1;...
# Alpha-state 4 up                       FOSL1;MARCKSL1;CREB5;GADD45B;SPTAN1;ATF3;EZH1;...
# Alpha-state 5 down                     TNFRSF12A;TRIM28;FOSB;GNPTG;TSR3;PTPRN;GABARAP...
# Alpha-state 5 up                       MGA;CNOT7;VPS37A;PHLPP2;RUNDC1;PDS5A;HP1BP3;NF...
# Alpha-state 6 down                     MGA;HNRNPAB;EZH1;PRPSAP1;MAP7D1;NOP56;POLR3E;T...
# Alpha-state 6 up                       CREB5;GADD45B;HMGA1;TOR1AIP1;ABHD2;SPHK1;TNFRS...
# Alpha1                                 SLC25A34;PYROXD2;REC8;ISM1;SYT10;C20orf196;DLG...
# Alpha2                                 FOSL1;MARCKSL1;MGA;ATF3;SH2D5;TAF5;ABHD2;CNOT7...
# Beta sub1_xin                                                        TUBB2A;TUBA4A;NPTX2
# Beta sub2_xin                                                              RPL6;FOS;JUNB
# Beta sub3_xin                                                                   CKB;CHGB
# Beta sub4_xin                          GADD45B;TNFRSF12A;CLGN;SRSF2;NXT1;PSMA3;NUDC;P...
# Beta-state1 genesdown                  ATF3;CNOT7;CLGN;RUNDC1;SFMBT1;TLK1;FOSB;DDX42;...
# Beta-state1 genesup                    SPTAN1;HMGA1;HNRNPAB;EZH1;PRPSAP1;MAP7D1;NOP56...
# Beta-state2 genesdown                  GADD45B;HMGA1;TOR1AIP1;HNRNPAB;ABHD2;PRPSAP1;T...
# Beta-state2 genesup                    MGA;ZNF652;ANKIB1;SLC41A2;TLK1;PSMA1;GABARAP;S...
# Beta-state3 genesdown                  SPTAN1;MGA;HNRNPAB;EZH1;PRPSAP1;VPS37A;MAP7D1;...
# Beta-state3 genesup                    GADD45B;STAG3;SFMBT1;FOSB;PSMA3;NUDC;RPLP0;IDE...
# Beta-state4 genesdown                  POLR3E;TLK1;GNPTG;PTPRN;PSMA1;GABARAP;RPLP0;PP...
# Beta-state4 genesup                    TOR1AIP1;MGA;ATF3;ABHD2;PRPSAP1;CNOT7;VPS37A;C...
# Beta1                                  PKP1;HTR1B;RP11-723O4.6;CYP7B1;CRADD;CDH20;FAM...
# Beta2                                  FOSL1;CREB5;ALOXE3;ANKRD30BL;HMGA1;TOR1AIP1;MG...
# ND_exocytosis_anticorrelated           NUDC;PPP1R15A;CNPPD1;DHPS;XRCC6;SESN2;RAB10;SL...
# ND_exocytosis_anticorrelated_filtered  NUDC;PPP1R15A;CNPPD1;DHPS;XRCC6;RAB10;SLBP;ANX...
# ND_exocytosis_correlated               MGA;ANKIB1;GPRIN1;SMARCC1;KARS;CDKN2C;SERTAD1;...
# ND_exocytosis_correlated_filtered      MGA;GPRIN1;KARS;MEST;TMEM259;MAVS;MAP1LC3A;MXR...
# T2D_exocytosis_anticorrelated          DEK;DEDD2;DNAJB1;SPG20;SMARCB1;UBE2I;FAHD1;ACT...
# T2D_exocytosis_correlated              SSH2;WDR37;CYB5D2;PIK3C2A;KMT2A;SOS1;ZCCHC2;PD...
# multi_correlated                       BIRC2;GPRIN1;RAI1;NPTX2;TRIP12;CACNA1C;SIN3A;M...
# mutli_anticorrelated                   DHPS;COQ6;SRXN1;NOL7;SLC3A2;RSF1;HGS;ANP32B;UG...

# %% [markdown]
# ## beta

# %%
gs_res=run_GSEA_gene('beta')
gs_res.res2d.sort_index()
# Out:
# (12988,)
# gene
# SLC2A13    40.521506
# Name: mlog10P, dtype: float64
# gene
# INS-IGF2   -36.40042
# Name: mlog10P, dtype: float64
#                                              es       nes      pval       fdr  \
# Term
# Alpha-state 1 down                     0.427283  1.459663  0.000000  0.012297
# Alpha-state 1 up                       0.393280  1.350049  0.000000  0.021285
# Alpha-state 2 down                     0.428845  1.461013  0.000000  0.013060
# Alpha-state 2 up                       0.400605  1.368350  0.000000  0.019831
# Alpha-state 3 down                     0.535820  1.806047  0.000000  0.000441
# Alpha-state 3 up                       0.361131  1.229148  0.000200  0.051281
# Alpha-state 4 down                     0.426146  1.464317  0.000000  0.013633
# Alpha-state 4 up                       0.444722  1.519411  0.000000  0.008979
# Alpha-state 5 down                     0.366388  1.240182  0.000400  0.048721
# Alpha-state 5 up                       0.446525  1.523107  0.000000  0.009545
# Alpha-state 6 down                     0.365275  1.251174  0.000000  0.046347
# Alpha-state 6 up                       0.489901  1.663491  0.000000  0.002472
# Alpha1                                -0.837088 -3.610603  0.000000  0.000000
# Alpha2                                 0.664856  2.217830  0.000000  0.000000
# Beta sub1_xin                          0.287611  0.664031  0.885204  0.981540
# Beta sub2_xin                         -0.548305 -1.785960  0.022552  0.020854
# Beta sub3_xin                         -0.780771 -2.073703  0.003374  0.005448
# Beta sub4_xin                          0.508191  1.687511  0.000000  0.002172
# Beta-state1 genesdown                  0.446705  1.511836  0.000000  0.008877
# Beta-state1 genesup                    0.394790  1.352725  0.000000  0.021755
# Beta-state2 genesdown                  0.414726  1.412208  0.000000  0.014223
# Beta-state2 genesup                    0.420684  1.430100  0.000000  0.012699
# Beta-state3 genesdown                  0.419968  1.441042  0.000000  0.012846
# Beta-state3 genesup                    0.412284  1.395577  0.000000  0.016121
# Beta-state4 genesdown                  0.390096  1.318347  0.000100  0.027078
# Beta-state4 genesup                    0.425730  1.455231  0.000000  0.011972
# Beta1                                 -1.000000 -4.441421  0.000000  0.000000
# Beta2                                  1.000000  3.350901  0.000000  0.000000
# ND_exocytosis_anticorrelated           0.522876  1.706043  0.000000  0.001898
# ND_exocytosis_anticorrelated_filtered  0.514801  1.660159  0.000000  0.002195
# ND_exocytosis_correlated               0.326755  1.068980  0.321371  0.229335
# ND_exocytosis_correlated_filtered      0.263695  0.838006  0.815188  0.947981
# T2D_exocytosis_anticorrelated          0.431891  1.437320  0.000100  0.012557
# T2D_exocytosis_correlated              0.413686  1.220189  0.167074  0.053183
# multi_correlated                      -0.252755 -0.965240  0.493168  0.486867
# mutli_anticorrelated                   0.527939  1.543921  0.007639  0.008343
#
#                                        geneset_size  matched_size  \
# Term
# Alpha-state 1 down                             2423          1949
# Alpha-state 1 up                               4578          3639
# Alpha-state 2 down                             1781          1436
# Alpha-state 2 up                               2262          1830
# Alpha-state 3 down                              821           614
# Alpha-state 3 up                               1533          1296
# Alpha-state 4 down                             5779          4705
# Alpha-state 4 up                               2535          2002
# Alpha-state 5 down                             1110           886
# Alpha-state 5 up                               1842          1483
# Alpha-state 6 down                             3302          2707
# Alpha-state 6 up                               1337          1021
# Alpha1                                          179            68
# Alpha2                                          500           383
# Beta sub1_xin                                    13            12
# Beta sub2_xin                                    28            17
# Beta sub3_xin                                    13             8
# Beta sub4_xin                                   390           355
# Beta-state1 genesdown                           981           788
# Beta-state1 genesup                            3385          2699
# Beta-state2 genesdown                          1784          1409
# Beta-state2 genesup                            1397          1114
# Beta-state3 genesdown                          4369          3505
# Beta-state3 genesup                            1126           912
# Beta-state4 genesdown                           989           807
# Beta-state4 genesup                            2354          1897
# Beta1                                           178            89
# Beta2                                           682           501
# ND_exocytosis_anticorrelated                    250           204
# ND_exocytosis_anticorrelated_filtered           191           158
# ND_exocytosis_correlated                        311           216
# ND_exocytosis_correlated_filtered               182           123
# T2D_exocytosis_anticorrelated                   449           360
# T2D_exocytosis_correlated                        77            53
# multi_correlated                                 57            40
# mutli_anticorrelated                             54            48
#
#                                                                                    genes  \
# Term
# Alpha-state 1 down                     CREB5;SEC23B;TOR1AIP1;POLR3A;ITGB1;SYDE2;SCG5;...
# Alpha-state 1 up                       WDR70;SESN2;ANO10;ATP6V1E2;DDIT3;MBD6;STK40;UB...
# Alpha-state 2 down                     ABHD2;SESN2;MBD6;SCG5;STK40;TNFRSF12A;MAML3;AC...
# Alpha-state 2 up                       SLC2A13;ANKRD28;FOSL2;WDR70;CALU;IGF1R;SYDE2;R...
# Alpha-state 3 down                     ANKRD28;CREB5;TOR1AIP1;SAMD4A;ABHD2;IGF1R;FNIP...
# Alpha-state 3 up                       SEC23B;SESN2;SCG5;UBAC2;RRAGA;IP6K2;ARPC5;PCK2...
# Alpha-state 4 down                     SEC23B;POLR3A;WDR70;ABHD2;SESN2;ANO10;NFAT5;DD...
# Alpha-state 4 up                       SLC2A13;ANKRD28;CREB5;DDX10;ITGB1;CALU;FNIP2;A...
# Alpha-state 5 down                     RHOQ;DDIT3;SCG5;TNFRSF12A;ERCC1;FAM134A;ETS1;P...
# Alpha-state 5 up                       SEC23B;DDX10;POLR3A;ITGB1;CALU;ANO10;SYDE2;NFA...
# Alpha-state 6 down                     DDX10;WDR70;IGF1R;SESN2;SYDE2;UBAC2;CAMTA2;TRI...
# Alpha-state 6 up                       ANKRD28;CREB5;TOR1AIP1;ITGB1;SAMD4A;ABHD2;FNIP...
# Alpha1                                 SREBF2;EMG1;SLC38A10;RFX6;ADCK1;GRM7;TTR;C20or...
# Alpha2                                 C8orf86;SEC23B;POLR3A;SH2D5;ABHD2;CALU;NFAT5;S...
# Beta sub1_xin                          TUBA4A;TUBB2A;NPTX2;TMED6;TAGLN2;ASCL2;SCGN;PP...
# Beta sub2_xin                          CDKN1C;RPL6;SPP1;SIX3;BTG2;IGFBP5;SCG2;NENF;ID...
# Beta sub3_xin                                      CHGB;CKB;TIMP1;CPE;DLK1;ASB9;CHGA;INS
# Beta sub4_xin                          DDIT3;IFRD1;CD55;TRIB3;TNFRSF12A;MTHFD2;OSER1;...
# Beta-state1 genesdown                  SLC2A13;CALU;ELP3;MTHFD2;EPM2A;ACTG1;CAST;ATF3...
# Beta-state1 genesup                    WDR70;SESN2;MBD6;STK40;UBAC2;DAGLB;USP20;CAMTA...
# Beta-state2 genesdown                  TOR1AIP1;ITGB1;ABHD2;MBD6;SCG5;GPHN;TNFRSF12A;...
# Beta-state2 genesup                    IGF1R;FNIP2;RHOQ;DDIT3;NCOA1;MTHFD2;CAST;FAM13...
# Beta-state3 genesdown                  SLC2A13;SEC23B;DDX10;POLR3A;WDR70;IGF1R;ANO10;...
# Beta-state3 genesup                    SESN2;FNIP2;SCG5;STK40;DAGLB;C9orf78;SETD2;ACT...
# Beta-state4 genesdown                  DDIT3;SCG5;CAMTA2;FAM134A;RNF187;PPP1R15A;CHAC...
# Beta-state4 genesup                    SLC2A13;SEC23B;TOR1AIP1;ITGB1;ABHD2;CALU;ABHD5...
# Beta1                                  GREB1L;PLXND1;MYLK3;DGKI;HTR1B;SSTR1;RNF125;SM...
# Beta2                                  SLC2A13;ANKRD28;C8orf86;CREB5;SEC23B;DDX10;TOR...
# ND_exocytosis_anticorrelated           SESN2;DDIT3;C9orf78;MTHFD2;CNPPD1;IP6K2;PPP1R1...
# ND_exocytosis_anticorrelated_filtered  DDIT3;C9orf78;MTHFD2;CNPPD1;IP6K2;PPP1R15A;SQS...
# ND_exocytosis_correlated               TRPM7;MGA;BNIP3L;DCAF6;BTBD10;CPD;FADS1;APP;FK...
# ND_exocytosis_correlated_filtered      MGA;BNIP3L;CPD;FADS1;APP;DCAF7;FAM46A;SURF2;TC...
# T2D_exocytosis_anticorrelated          ITGB1;DEK;CELF2;ATP5G1;ACTN1;CTNNAL1;UBE2I;LAR...
# T2D_exocytosis_correlated              SCG5;GPHN;STRBP;KMT2A;CYB5D2;SOS1;ZFYVE16;NR4A...
# multi_correlated                       BIRC2;SIN3A;LRCH4;CMC1;STAT3;PAXBP1;SNX27;NPTX...
# mutli_anticorrelated                   MTHFD2;ADK;SCAND1;SARS;ANP32B;DNTTIP2;SIGMAR1;...
#
#                                                                              ledge_genes
# Term
# Alpha-state 1 down                     CREB5;SEC23B;TOR1AIP1;POLR3A;ITGB1;SYDE2;SCG5;...
# Alpha-state 1 up                       WDR70;SESN2;ANO10;ATP6V1E2;DDIT3;MBD6;STK40;UB...
# Alpha-state 2 down                     ABHD2;SESN2;MBD6;SCG5;STK40;TNFRSF12A;MAML3;AC...
# Alpha-state 2 up                       SLC2A13;ANKRD28;FOSL2;WDR70;CALU;IGF1R;SYDE2;R...
# Alpha-state 3 down                     ANKRD28;CREB5;TOR1AIP1;SAMD4A;ABHD2;IGF1R;FNIP...
# Alpha-state 3 up                       SEC23B;SESN2;SCG5;UBAC2;RRAGA;IP6K2;ARPC5;PCK2...
# Alpha-state 4 down                     SEC23B;POLR3A;WDR70;ABHD2;SESN2;ANO10;NFAT5;DD...
# Alpha-state 4 up                       SLC2A13;ANKRD28;CREB5;DDX10;ITGB1;CALU;FNIP2;A...
# Alpha-state 5 down                     RHOQ;DDIT3;SCG5;TNFRSF12A;ERCC1;FAM134A;ETS1;P...
# Alpha-state 5 up                       SEC23B;DDX10;POLR3A;ITGB1;CALU;ANO10;SYDE2;NFA...
# Alpha-state 6 down                     DDX10;WDR70;IGF1R;SESN2;SYDE2;UBAC2;CAMTA2;TRI...
# Alpha-state 6 up                       ANKRD28;CREB5;TOR1AIP1;ITGB1;SAMD4A;ABHD2;FNIP...
# Alpha1                                 SEPT9;SYT10;PDZK1;CCKAR;PCDH15;AL136376.1;AK5;...
# Alpha2                                 C8orf86;SEC23B;POLR3A;SH2D5;ABHD2;CALU;NFAT5;S...
# Beta sub1_xin                                                        TUBA4A;TUBB2A;NPTX2
# Beta sub2_xin                                                             RGS16;RBP1;ID1
# Beta sub3_xin                                                         DLK1;ASB9;CHGA;INS
# Beta sub4_xin                          DDIT3;IFRD1;CD55;TRIB3;TNFRSF12A;MTHFD2;OSER1;...
# Beta-state1 genesdown                  SLC2A13;CALU;ELP3;MTHFD2;EPM2A;ACTG1;CAST;ATF3...
# Beta-state1 genesup                    WDR70;SESN2;MBD6;STK40;UBAC2;DAGLB;USP20;CAMTA...
# Beta-state2 genesdown                  TOR1AIP1;ITGB1;ABHD2;MBD6;SCG5;GPHN;TNFRSF12A;...
# Beta-state2 genesup                    IGF1R;FNIP2;RHOQ;DDIT3;NCOA1;MTHFD2;CAST;FAM13...
# Beta-state3 genesdown                  SLC2A13;SEC23B;DDX10;POLR3A;WDR70;IGF1R;ANO10;...
# Beta-state3 genesup                    SESN2;FNIP2;SCG5;STK40;DAGLB;C9orf78;SETD2;ACT...
# Beta-state4 genesdown                  DDIT3;SCG5;CAMTA2;FAM134A;RNF187;PPP1R15A;CHAC...
# Beta-state4 genesup                    SLC2A13;SEC23B;TOR1AIP1;ITGB1;ABHD2;CALU;ABHD5...
# Beta1                                  GREB1L;PLXND1;MYLK3;DGKI;HTR1B;SSTR1;RNF125;SM...
# Beta2                                  SLC2A13;ANKRD28;C8orf86;CREB5;SEC23B;DDX10;TOR...
# ND_exocytosis_anticorrelated           SESN2;DDIT3;C9orf78;MTHFD2;CNPPD1;IP6K2;PPP1R1...
# ND_exocytosis_anticorrelated_filtered  DDIT3;C9orf78;MTHFD2;CNPPD1;IP6K2;PPP1R15A;SQS...
# ND_exocytosis_correlated               TRPM7;MGA;BNIP3L;DCAF6;BTBD10;CPD;FADS1;APP;FK...
# ND_exocytosis_correlated_filtered      MGA;BNIP3L;CPD;FADS1;APP;DCAF7;FAM46A;SURF2;TC...
# T2D_exocytosis_anticorrelated          ITGB1;DEK;CELF2;ATP5G1;ACTN1;CTNNAL1;UBE2I;LAR...
# T2D_exocytosis_correlated              SCG5;GPHN;STRBP;KMT2A;CYB5D2;SOS1;ZFYVE16;NR4A...
# multi_correlated                                                 KCNH2;BMP5;CHGA;FAM159B
# mutli_anticorrelated                   MTHFD2;ADK;SCAND1;SARS;ANP32B;DNTTIP2;SIGMAR1;...

# %% [markdown]
# ## delta

# %%
gs_res_d=run_GSEA_gene('delta')
gs_res_d.res2d.sort_index()
# Out:
# (12818,)
# gene
# CDS1    4.778295
# Name: mlog10P, dtype: float64
# gene
# USP5   -2.942512
# Name: mlog10P, dtype: float64
#                                              es       nes      pval       fdr  \
# Term
# Alpha-state 1 down                     0.258303  1.299326  0.000000  0.091291
# Alpha-state 1 up                       0.191305  0.966744  0.726400  0.632640
# Alpha-state 2 down                     0.234560  1.174814  0.020500  0.149299
# Alpha-state 2 up                       0.257793  1.295272  0.000000  0.087245
# Alpha-state 3 down                     0.342205  1.681232  0.000000  0.017063
# Alpha-state 3 up                       0.205072  1.026909  0.388739  0.481520
# Alpha-state 4 down                     0.223898  1.133118  0.003800  0.199395
# Alpha-state 4 up                       0.288080  1.449142  0.000000  0.049060
# Alpha-state 5 down                     0.200145  0.995626  0.516019  0.559133
# Alpha-state 5 up                       0.266779  1.337295  0.000000  0.081982
# Alpha-state 6 down                     0.202246  1.021056  0.364600  0.488869
# Alpha-state 6 up                       0.315243  1.572687  0.000000  0.029118
# Alpha1                                -0.580817 -3.191180  0.000000  0.000000
# Alpha2                                 0.490754  2.367651  0.000000  0.000000
# Beta sub1_xin                          0.453987  1.252012  0.210165  0.099111
# Beta sub2_xin                         -0.150740 -0.551111  0.964956  0.978278
# Beta sub3_xin                          0.464200  1.064503  0.401455  0.363145
# Beta sub4_xin                          0.304588  1.463977  0.002367  0.049585
# Beta-state1 genesdown                  0.269501  1.335384  0.001903  0.076200
# Beta-state1 genesup                    0.198575  1.001653  0.490600  0.552816
# Beta-state2 genesdown                  0.235891  1.181941  0.019300  0.147166
# Beta-state2 genesup                    0.268490  1.339199  0.000300  0.089038
# Beta-state3 genesdown                  0.229889  1.161714  0.001500  0.159937
# Beta-state3 genesup                    0.256800  1.276895  0.005405  0.093602
# Beta-state4 genesdown                  0.195285  0.968119  0.611468  0.648011
# Beta-state4 genesup                    0.250290  1.258082  0.000200  0.100746
# Beta1                                 -0.447621 -2.512725  0.000000  0.000000
# Beta2                                  0.454896  2.221149  0.000000  0.000000
# ND_exocytosis_anticorrelated           0.323648  1.496160  0.005477  0.044823
# ND_exocytosis_anticorrelated_filtered  0.350641  1.577750  0.003438  0.034798
# ND_exocytosis_correlated               0.233488  1.092362  0.299798  0.285703
# ND_exocytosis_correlated_filtered      0.203143  0.894523  0.666591  0.805732
# T2D_exocytosis_anticorrelated          0.286012  1.377881  0.008201  0.074617
# T2D_exocytosis_correlated              0.309354  1.195252  0.218710  0.146242
# multi_correlated                       0.278141  1.032863  0.421816  0.473651
# mutli_anticorrelated                   0.317727  1.184243  0.241030  0.152016
#
#                                        geneset_size  matched_size  \
# Term
# Alpha-state 1 down                             2423          2014
# Alpha-state 1 up                               4578          3796
# Alpha-state 2 down                             1781          1483
# Alpha-state 2 up                               2262          1913
# Alpha-state 3 down                              821           628
# Alpha-state 3 up                               1533          1332
# Alpha-state 4 down                             5779          4884
# Alpha-state 4 up                               2535          2111
# Alpha-state 5 down                             1110           917
# Alpha-state 5 up                               1842          1541
# Alpha-state 6 down                             3302          2816
# Alpha-state 6 up                               1337          1071
# Alpha1                                          179           105
# Alpha2                                          500           397
# Beta sub1_xin                                    13            13
# Beta sub2_xin                                    28            20
# Beta sub3_xin                                    13             7
# Beta sub4_xin                                   390           348
# Beta-state1 genesdown                           981           807
# Beta-state1 genesup                            3385          2818
# Beta-state2 genesdown                          1784          1469
# Beta-state2 genesup                            1397          1163
# Beta-state3 genesdown                          4369          3682
# Beta-state3 genesup                            1126           929
# Beta-state4 genesdown                           989           811
# Beta-state4 genesup                            2354          1982
# Beta1                                           178           120
# Beta2                                           682           503
# ND_exocytosis_anticorrelated                    250           207
# ND_exocytosis_anticorrelated_filtered           191           157
# ND_exocytosis_correlated                        311           239
# ND_exocytosis_correlated_filtered               182           135
# T2D_exocytosis_anticorrelated                   449           381
# T2D_exocytosis_correlated                        77            57
# multi_correlated                                 57            46
# mutli_anticorrelated                             54            47
#
#                                                                                    genes  \
# Term
# Alpha-state 1 down                     CDS1;GADD45B;HBP1;PLK2;MARCKS;UBC;PSIP1;C9orf1...
# Alpha-state 1 up                       MED20;SLC35B2;COMMD1;TYMP;PCIF1;GPATCH3;EPPK1;...
# Alpha-state 2 down                     HSPA1B;GADD45B;SLC35B2;UBC;PCIF1;NUDC;CRY1;GDI...
# Alpha-state 2 up                       RB1CC1;ANKRD28;HBP1;PPP3CA;MARCKS;COMMD1;PSIP1...
# Alpha-state 3 down                     RB1CC1;HSPA1B;ANKRD28;MARCKS;UBC;ADNP2;ATF3;TR...
# Alpha-state 3 up                       PLK2;PPP3CA;SLC35B2;CCT4;CYSTM1;APOA1BP;AUH;WB...
# Alpha-state 4 down                     CDS1;RB1CC1;HBP1;PLK2;PPP3CA;MARCKS;SLC35B2;C9...
# Alpha-state 4 up                       ZNF791;HSPA1B;GADD45B;ANKRD28;MED20;AZIN1;COMM...
# Alpha-state 5 down                     HSPA1B;PPP3CA;MARCKS;UBC;PCIF1;CYSTM1;FAM134A;...
# Alpha-state 5 up                       MED20;AZIN1;CCT4;DNAJC6;DDX5;C1orf63;TRAM1;LBH...
# Alpha-state 6 down                     HSPA1B;PLK2;MARCKS;SLC35B2;COMMD1;CCT4;PSIP1;E...
# Alpha-state 6 up                       RB1CC1;ZNF791;GADD45B;ANKRD28;AZIN1;UBC;NUDC;T...
# Alpha1                                 PSMF1;ZDHHC2;GALNT8;SMEK1;FEV;P2RY14;MYBPHL;CH...
# Alpha2                                 MED20;CCT4;FTCD;C1orf63;ATF3;CCDC70;CYSTM1;FAM...
# Beta sub1_xin                          TUBA4A;TMED6;RBP4;PPP1R1A;NPTX2;ASCL2;TUBB2A;F...
# Beta sub2_xin                          FOS;IGFBP5;RPL6;JUNB;RPS4X;RASD1;RGS16;SIX3;PC...
# Beta sub3_xin                                        CKB;CPE;CHGA;ASB9;TIMP1;CHGB;IGFBP7
# Beta sub4_xin                          HSPA1B;GADD45B;CCT4;UBC;NUDC;TRAM1;PNO1;CYSTM1...
# Beta-state1 genesdown                  CDS1;HSPA1B;MED20;UBC;PSIP1;C9orf156;DDX5;C1or...
# Beta-state1 genesup                    PLK2;SLC35B2;PCIF1;NUDC;GPATCH3;CYSTM1;FAM134A...
# Beta-state2 genesdown                  GADD45B;SLC35B2;UBC;PCIF1;NUDC;CRY1;TRAM1;GDI1...
# Beta-state2 genesup                    RB1CC1;PPP3CA;MARCKS;PSIP1;QKI;POGZ;NCOA1;TRIO...
# Beta-state3 genesdown                  MED20;PPP3CA;MARCKS;AZIN1;SLC35B2;PSIP1;EFR3A;...
# Beta-state3 genesup                    GADD45B;PLK2;UBC;C9orf156;NUDC;C1orf63;CRY1;EX...
# Beta-state4 genesdown                  HSPA1B;PPP3CA;MARCKS;CYSTM1;FAM134A;MT1X;TPI1;...
# Beta-state4 genesup                    ZNF791;MED20;AZIN1;SLC35B2;CCT4;EFR3A;DNAJC6;D...
# Beta1                                  LDLRAD3;XIRP2;BTBD3;B3GNT5;SMEK1;LRRC29;MYBPHL...
# Beta2                                  ANKRD28;HBP1;AZIN1;SLC35B2;UBC;PSIP1;C9orf156;...
# ND_exocytosis_anticorrelated           UBC;NUDC;CNPPD1;AP5M1;DTNB;HSPA4L;TUBA4A;SF3B5...
# ND_exocytosis_anticorrelated_filtered  UBC;NUDC;CNPPD1;AP5M1;TUBA4A;SF3B5;INTS10;RAB1...
# ND_exocytosis_correlated               ZBED3;DNAJC5;PPIL4;ELMO2;PTMS;CHD7;SGMS1;TSPAN...
# ND_exocytosis_correlated_filtered      PPIL4;CHD7;TSPAN2;MAVS;MRPL14;MGA;NR4A1;ANKRD3...
# T2D_exocytosis_anticorrelated          PLK2;SLC35B2;CCT4;TRIO;BTBD9;UBE2E2;ACTB;NEIL2...
# T2D_exocytosis_correlated              APBB3;PRRC1;EXT2;RGS9;SOS1;STRBP;WDR37;NR4A2;P...
# multi_correlated                       CAMK2B;TSPAN2;C21orf91;TRIP12;GPRIN1;SEPT3;PLE...
# mutli_anticorrelated                   ANP32B;CTSB;ID2;SIGMAR1;DLD;COQ6;SCAND1;RBP4;T...
#
#                                                                              ledge_genes
# Term
# Alpha-state 1 down                     CDS1;GADD45B;HBP1;PLK2;MARCKS;UBC;PSIP1;C9orf1...
# Alpha-state 1 up                       MED20;SLC35B2;COMMD1;TYMP;PCIF1;GPATCH3;EPPK1;...
# Alpha-state 2 down                     HSPA1B;GADD45B;SLC35B2;UBC;PCIF1;NUDC;CRY1;GDI...
# Alpha-state 2 up                       RB1CC1;ANKRD28;HBP1;PPP3CA;MARCKS;COMMD1;PSIP1...
# Alpha-state 3 down                     RB1CC1;HSPA1B;ANKRD28;MARCKS;UBC;ADNP2;ATF3;TR...
# Alpha-state 3 up                       PLK2;PPP3CA;SLC35B2;CCT4;CYSTM1;APOA1BP;AUH;WB...
# Alpha-state 4 down                     CDS1;RB1CC1;HBP1;PLK2;PPP3CA;MARCKS;SLC35B2;C9...
# Alpha-state 4 up                       ZNF791;HSPA1B;GADD45B;ANKRD28;MED20;AZIN1;COMM...
# Alpha-state 5 down                     HSPA1B;PPP3CA;MARCKS;UBC;PCIF1;CYSTM1;FAM134A;...
# Alpha-state 5 up                       MED20;AZIN1;CCT4;DNAJC6;DDX5;C1orf63;TRAM1;LBH...
# Alpha-state 6 down                     HSPA1B;PLK2;MARCKS;SLC35B2;COMMD1;CCT4;PSIP1;E...
# Alpha-state 6 up                       RB1CC1;ZNF791;GADD45B;ANKRD28;AZIN1;UBC;NUDC;T...
# Alpha1                                 PDSS1;CTBP1;CCDC6;TRHDE;RP11-257K9.8;SLC2A9;ND...
# Alpha2                                 MED20;CCT4;FTCD;C1orf63;ATF3;CCDC70;CYSTM1;FAM...
# Beta sub1_xin                                            TUBA4A;TMED6;RBP4;PPP1R1A;NPTX2
# Beta sub2_xin                                           GPX3;NENF;CDKN1C;BTG2;PEMT;STMN2
# Beta sub3_xin                                               CKB;CPE;CHGA;ASB9;TIMP1;CHGB
# Beta sub4_xin                          HSPA1B;GADD45B;CCT4;UBC;NUDC;TRAM1;PNO1;CYSTM1...
# Beta-state1 genesdown                  CDS1;HSPA1B;MED20;UBC;PSIP1;C9orf156;DDX5;C1or...
# Beta-state1 genesup                    PLK2;SLC35B2;PCIF1;NUDC;GPATCH3;CYSTM1;FAM134A...
# Beta-state2 genesdown                  GADD45B;SLC35B2;UBC;PCIF1;NUDC;CRY1;TRAM1;GDI1...
# Beta-state2 genesup                    RB1CC1;PPP3CA;MARCKS;PSIP1;QKI;POGZ;NCOA1;TRIO...
# Beta-state3 genesdown                  MED20;PPP3CA;MARCKS;AZIN1;SLC35B2;PSIP1;EFR3A;...
# Beta-state3 genesup                    GADD45B;PLK2;UBC;C9orf156;NUDC;C1orf63;CRY1;EX...
# Beta-state4 genesdown                  HSPA1B;PPP3CA;MARCKS;CYSTM1;FAM134A;MT1X;TPI1;...
# Beta-state4 genesup                    ZNF791;MED20;AZIN1;SLC35B2;CCT4;EFR3A;DNAJC6;D...
# Beta1                                  CACFD1;C1orf168;MYLK3;OLFM1;TMEM229A;SLC16A14;...
# Beta2                                  ANKRD28;HBP1;AZIN1;SLC35B2;UBC;PSIP1;C9orf156;...
# ND_exocytosis_anticorrelated           UBC;NUDC;CNPPD1;AP5M1;DTNB;HSPA4L;TUBA4A;SF3B5...
# ND_exocytosis_anticorrelated_filtered  UBC;NUDC;CNPPD1;AP5M1;TUBA4A;SF3B5;INTS10;RAB1...
# ND_exocytosis_correlated               ZBED3;DNAJC5;PPIL4;ELMO2;PTMS;CHD7;SGMS1;TSPAN...
# ND_exocytosis_correlated_filtered      PPIL4;CHD7;TSPAN2;MAVS;MRPL14;MGA;NR4A1;ANKRD3...
# T2D_exocytosis_anticorrelated          PLK2;SLC35B2;CCT4;TRIO;BTBD9;UBE2E2;ACTB;NEIL2...
# T2D_exocytosis_correlated              APBB3;PRRC1;EXT2;RGS9;SOS1;STRBP;WDR37;NR4A2;P...
# multi_correlated                       CAMK2B;TSPAN2;C21orf91;TRIP12;GPRIN1;SEPT3;PLE...
# mutli_anticorrelated                   ANP32B;CTSB;ID2;SIGMAR1;DLD;COQ6;SCAND1;RBP4;T...

# %% [markdown]
# ### Save results

# %%
gs_res.res2d[['es','nes','pval','fdr','geneset_size','matched_size']].to_csv('../dat/figdata/GSEA_beta_all_seed1000_p10000_rev.csv')
gs_res_a.res2d[['es','nes','pval','fdr','geneset_size','matched_size']].to_csv('../dat/figdata/GSEA_alpha_all_seed1000_p10000_rev.csv')
gs_res_d.res2d[['es','nes','pval','fdr','geneset_size','matched_size']].to_csv('../dat/figdata/GSEA_delta_all_seed1000_p10000_rev.csv')

from gseapy.plot import gseaplot, heatmap
terms = gs_res.res2d.index 
for i in range(len(terms)):
    gseaplot(gs_res.ranking, term=terms[i], **gs_res.results[terms[i]],ofname=terms[i]+'_beta_all_seed1000_p10000_rev.pdf')
terms = gs_res_a.res2d.index 
for i in range(len(terms)):
    gseaplot(gs_res_a.ranking, term=terms[i], **gs_res_a.results[terms[i]],ofname=terms[i]+'_alpha_seed1000_p10000_rev.pdf')
terms = gs_res_a.res2d.index 
for i in range(len(terms)):
    gseaplot(gs_res_a.ranking, term=terms[i], **gs_res_a.results[terms[i]],ofname=terms[i]+'_delta_all_seed1000_p10000_rev.pdf')
