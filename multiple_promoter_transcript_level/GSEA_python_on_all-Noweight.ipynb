# %% [markdown]
# # Perform GSEA using GSEAPY
#
# Following the potocol defined here: https://gseapy.readthedocs.io/en/latest/gseapy_tutorial.html#use-gsea-command-or-gsea

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina' # mac
import pandas as pd
import gseapy as gp
import numpy as np
import matplotlib.pyplot as plt

# %%
gp.__version__
# Out:
# '0.9.9'

# %%
def run_GSEA_gene(celltype='alpha',
             rnkfile="../dat/figdata/fig2_prom_ttest_res_genelevel.csv",
             glist='../dat/glists/gsea_all.gmt'):
    gene_exp_alpha = pd.read_csv(rnkfile,index_col=1)
    #gene_exp_alpha.head()
    rnk = gene_exp_alpha.loc[(gene_exp_alpha["celltype"]==celltype) & (~gene_exp_alpha["isAmbious"])].sort_values(by='mlog10P')["mlog10P"]

    print(rnk.shape)
    print(rnk.head(1))
    print(rnk.tail(1))

    gs_res_a = gp.prerank(rnk=rnk, # or data='./P53_resampling_data.txt'
                     gene_sets=glist, # enrichr library names or gmt file
                     #set permutation_type to phenotype if samples >=15
                     permutation_num=10000, # reduce number to speed up test
                     outdir=None,  # do not write output to disk
                     no_plot=True, # Skip plotting
                     weighted_score_type=0,
                     #ascending=False,
                        seed=1000,
                     min_size=1,
                     max_size=5000,
                     processes=8)
                     #format='png')
    return(gs_res_a)

# %% [markdown]
# ## alpha

# %%
gs_res_a=run_GSEA_gene('alpha')
gs_res_a.res2d.sort_index()
# Out:
# (13130,)
# gene
# FOSL1   -34.795613
# Name: mlog10P, dtype: float64
# gene
# SPAG16    24.642316
# Name: mlog10P, dtype: float64
#                                              es        nes      pval  \
# Term
# Alpha-state 1 down                    -0.155033  -7.366660  0.000000
# Alpha-state 1 up                      -0.191691 -11.370169  0.000000
# Alpha-state 2 down                    -0.193246  -7.969225  0.000000
# Alpha-state 2 up                      -0.123456  -5.729493  0.000000
# Alpha-state 3 down                    -0.246412  -6.924390  0.000000
# Alpha-state 3 up                      -0.113119  -4.496312  0.000000
# Alpha-state 4 down                    -0.198612 -12.644754  0.000000
# Alpha-state 4 up                      -0.156485  -7.485480  0.000000
# Alpha-state 5 down                    -0.129438  -4.363101  0.000000
# Alpha-state 5 up                      -0.176696  -7.406839  0.000000
# Alpha-state 6 down                    -0.132056  -7.105486  0.000000
# Alpha-state 6 up                      -0.209702  -7.391082  0.000000
# Alpha1                                 1.000000   9.691590  0.000000
# Alpha2                                -1.000000 -42.908724  0.000000
# Beta sub1_xin                          0.249936   1.060877  0.368505
# Beta sub2_xin                          0.135770   0.737933  0.796381
# Beta sub3_xin                          0.300544   0.907601  0.568408
# Beta sub4_xin                         -0.198688  -4.244429  0.000000
# Beta-state1 genesdown                 -0.167853  -5.299250  0.000000
# Beta-state1 genesup                   -0.191799 -10.271748  0.000000
# Beta-state2 genesdown                 -0.175761  -7.246134  0.000000
# Beta-state2 genesup                   -0.163050  -5.995870  0.000000
# Beta-state3 genesdown                 -0.169849  -9.895346  0.000000
# Beta-state3 genesup                   -0.171333  -5.865782  0.000000
# Beta-state4 genesdown                 -0.166320  -5.351635  0.000000
# Beta-state4 genesup                   -0.136471  -6.361330  0.000000
# Beta1                                  0.618840   6.777493  0.000000
# Beta2                                 -0.584692 -14.853983  0.000000
# ND_exocytosis_anticorrelated          -0.215164  -3.492398  0.000000
# ND_exocytosis_anticorrelated_filtered -0.223622  -3.167796  0.000000
# ND_exocytosis_correlated              -0.097668  -1.698695  0.028310
# ND_exocytosis_correlated_filtered     -0.089538  -1.185083  0.244454
# T2D_exocytosis_anticorrelated         -0.168763  -3.702978  0.000000
# T2D_exocytosis_correlated             -0.145157  -1.292338  0.163871
# multi_correlated                      -0.121968  -0.930164  0.533079
# mutli_anticorrelated                  -0.211935  -1.690666  0.030346
#
#                                             fdr  geneset_size  matched_size  \
# Term
# Alpha-state 1 down                     0.000000          2423          1961
# Alpha-state 1 up                       0.000000          4578          3696
# Alpha-state 2 down                     0.000000          1781          1434
# Alpha-state 2 up                       0.000000          2262          1832
# Alpha-state 3 down                     0.000000           821           616
# Alpha-state 3 up                       0.000000          1533          1286
# Alpha-state 4 down                     0.000000          5779          4727
# Alpha-state 4 up                       0.000000          2535          2021
# Alpha-state 5 down                     0.000000          1110           900
# Alpha-state 5 up                       0.000000          1842          1470
# Alpha-state 6 down                     0.000000          3302          2731
# Alpha-state 6 up                       0.000000          1337          1016
# Alpha1                                 0.000000           179            68
# Alpha2                                 0.000000          1967          1578
# Beta sub1_xin                          0.606141            13            12
# Beta sub2_xin                          0.803095            28            21
# Beta sub3_xin                          0.703199            13             6
# Beta sub4_xin                          0.000000           390           351
# Beta-state1 genesdown                  0.000000           981           799
# Beta-state1 genesup                    0.000000          3385          2738
# Beta-state2 genesdown                  0.000000          1784          1433
# Beta-state2 genesup                    0.000000          1397          1103
# Beta-state3 genesdown                  0.000000          4369          3499
# Beta-state3 genesup                    0.000000          1126           939
# Beta-state4 genesdown                  0.000000           989           814
# Beta-state4 genesup                    0.000000          2354          1904
# Beta1                                  0.000000           178            87
# Beta2                                  0.000000           682           499
# ND_exocytosis_anticorrelated           0.000000           250           197
# ND_exocytosis_anticorrelated_filtered  0.000000           191           151
# ND_exocytosis_correlated               0.030221           311           224
# ND_exocytosis_correlated_filtered      0.249539           182           130
# T2D_exocytosis_anticorrelated          0.000000           449           365
# T2D_exocytosis_correlated              0.173865            77            56
# multi_correlated                       0.529933            57            41
# mutli_anticorrelated                   0.030383            54            46
#
#                                                                                    genes  \
# Term
# Alpha-state 1 down                     GCG;KCNA5;CERKL;LANCL1;TTC14;ARRDC3;EMB;PDZK1;...
# Alpha-state 1 up                       TTR;SND1;FEV;NEUROD1;EPHX1;NDRG1;PTPN6;NUPR1L;...
# Alpha-state 2 down                     TTR;SND1;FEV;EPHX1;NUPR1L;CHGA;SH3TC1;ANXA6;RE...
# Alpha-state 2 up                       GCG;SLC30A8;HTR1F;PCDH17;TTC14;ARRDC3;SLC7A2;R...
# Alpha-state 3 down                     PCDH17;ARRDC3;TNS3;RPS26;TFF3;GSTM2;FABP5;CENP...
# Alpha-state 3 up                       SPAG16;GCG;SND1;NEUROD1;SLC30A8;NDRG1;NUPR1L;S...
# Alpha-state 4 down                     SND1;KCNA5;NEUROD1;EPHX1;NDRG1;HTR1F;ZNF736;PT...
# Alpha-state 4 up                       SPAG16;TTR;C1orf168;SLC30A8;PCDH17;EMG1;MOB4;T...
# Alpha-state 5 down                     TTR;C1orf168;FEV;NUPR1L;CHGA;IDNK;SPINK4;TMEM8...
# Alpha-state 5 up                       SND1;KCNA5;NEUROD1;HTR1F;ZNF736;RSAD2;HIST1H2B...
# Alpha-state 6 down                     SPAG16;KCNA5;NEUROD1;EPHX1;SLC30A8;NDRG1;PTPN6...
# Alpha-state 6 up                       CHGA;SH3TC1;ANXA6;LMO7;PRR26;TAPBPL;SERPINB1;L...
# Alpha1                                 SPAG16;GCG;TTR;TMEM72;SEMA6A;SND1;C1orf168;KCN...
# Alpha2                                 CDKL5;MAP1S;PLOD3;ZNHIT1;PIGF;CRIPT;TMED2;TOP1...
# Beta sub1_xin                          PPP1R1A;SCGB2A1;SCGN;RBP4;FFAR4;PRSS23;ASCL2;T...
# Beta sub2_xin                          TFF3;RBP1;NPY;IAPP;IGFBP5;GPX3;ID1;SPP1;SIX3;S...
# Beta sub3_xin                                                CHGA;INS;TIMP1;CPE;CHGB;CKB
# Beta sub4_xin                          GCG;AUP1;LURAP1L;HIST1H1C;GDF15;CHCHD2;TMEM176...
# Beta-state1 genesdown                  SLC30A8;HTR1F;ARRDC3;G6PC2;MANBA;UFM1;MMRN1;CN...
# Beta-state1 genesup                    GCG;TTR;SND1;FEV;EPHX1;NDRG1;PTPN6;NUPR1L;CHGA...
# Beta-state2 genesdown                  GCG;SND1;EPHX1;NDRG1;NUPR1L;CHGA;SH3TC1;ANXA6;...
# Beta-state2 genesup                    ARRDC3;SLC25A34;NECAB1;MYT1L;KCNJ3;ADH5;PIP4K2...
# Beta-state3 genesdown                  GCG;SEMA6A;SND1;NEUROD1;NDRG1;PTPN6;LANCL1;HIS...
# Beta-state3 genesup                    KCNA5;EMG1;MOB4;DUSP26;KLHL3;ATP5B;PPP1R1A;MRP...
# Beta-state4 genesdown                  GCG;TTR;HIST1H2BD;KCNJ3;LGALS3BP;KIF12;FAM159B...
# Beta-state4 genesup                    SND1;KCNA5;NEUROD1;SLC30A8;ZNF736;PTPN6;DHRS2;...
# Beta1                                  SPAG16;C1orf168;KCNA5;NEUROD1;CERKL;EPHX1;MYBP...
# Beta2                                  TNS3;ZMAT4;ABCB1;MARS;ZNF169;SLC7A11;SERTAD4;R...
# ND_exocytosis_anticorrelated           ATP5B;PSPH;SLC35A3;MAGEH1;NUDT5;SEC23IP;ARMCX6...
# ND_exocytosis_anticorrelated_filtered  ATP5B;PSPH;MAGEH1;NUDT5;ARMCX6;ATAD3C;PDCD10;A...
# ND_exocytosis_correlated               SLC30A8;CELF3;ARHGEF9;MRPL16;FAM159B;CD14;PICK...
# ND_exocytosis_correlated_filtered      SLC30A8;MRPL16;FAM159B;CD14;RBP1;HERC2;GSTK1;T...
# T2D_exocytosis_anticorrelated          SPAG16;SND1;TMEM218;AKR1B1;C10orf10;GRAMD1A;LI...
# T2D_exocytosis_correlated              TTR;CHGA;CELF3;SCGB2A1;CST3;AP1G2;GPD2;WDR55;C...
# multi_correlated                       SLC30A8;CHGA;FAM159B;GSTK1;GRIA4;BMP5;VWDE;GPX...
# mutli_anticorrelated                   ATP5B;MAGEH1;RBP4;EIF4EBP1;SLC25A6;NDUFA9;RUVB...
#
#                                                                              ledge_genes
# Term
# Alpha-state 1 down                     SPRYD7;ZNF394;MAPK9;TCF7L2;COMMD3;GUCY1A3;ZNF3...
# Alpha-state 1 up                       RPL26L1;SMOC1;ABCD1;BCAP31;RNASET2;POLR2J;C9or...
# Alpha-state 2 down                     RBM3;STOML2;LPCAT3;WNT4;EIF3F;ELOF1;ECHDC3;LSR...
# Alpha-state 2 up                       TRNT1;GPATCH2;LSG1;SLC39A9;NDUFC2;GPATCH1;C5or...
# Alpha-state 3 down                     XPO6;TCERG1;POM121C;ACTN4;ARHGAP21;UHRF1BP1L;C...
# Alpha-state 3 up                       POMP;MRPS28;RPL26L1;SMOC1;POLR2J;APOA1BP;SGSM3...
# Alpha-state 4 down                     ZNF280B;L2HGDH;GTF3A;TOR3A;GTF3C1;KIAA0556;DPP...
# Alpha-state 4 up                       PEF1;SP1;FAM58A;CNBP;TOP2B;RPL41;ZNF655;RNLS;C...
# Alpha-state 5 down                     SEC11C;NDUFB1;U2AF1L4;PSENEN;RPS13;TXNL4A;RPL1...
# Alpha-state 5 up                       UQCRFS1;RAB1A;SC5D;TADA1;MAN2A1;PDCL3;ACVR1C;P...
# Alpha-state 6 down                     CKLF;SPRYD7;MAPK9;MRPL46;COMMD3;GUCY1A3;SMC2;V...
# Alpha-state 6 up                       XPO6;TCERG1;TMEM43;ATG7;POM121C;C21orf2;ACTN4;...
# Alpha1                                 SPAG16;GCG;TTR;TMEM72;SEMA6A;SND1;C1orf168;KCN...
# Alpha2                                 CDKL5;MAP1S;PLOD3;ZNHIT1;PIGF;CRIPT;TMED2;TOP1...
# Beta sub1_xin                                                  PPP1R1A;SCGB2A1;SCGN;RBP4
# Beta sub2_xin                          TFF3;RBP1;NPY;IAPP;IGFBP5;GPX3;ID1;SPP1;SIX3;S...
# Beta sub3_xin                                                         CHGA;INS;TIMP1;CPE
# Beta sub4_xin                          MYL12B;GHITM;UPP1;IER2;MANF;CDC37L1;RER1;DERL2...
# Beta-state1 genesdown                  TBP;RBBP5;RPA1;HSPA1B;CWF19L2;C1orf174;TFDP1;V...
# Beta-state1 genesup                    RAB17;CDK5;C2CD4B;UQCC2;STOML2;PEX12;LPCAT3;OG...
# Beta-state2 genesdown                  FAM195A;FAAH;DNAJC14;ZKSCAN8;ATP5D;FKBP8;AVL9;...
# Beta-state2 genesup                    CKLF;TCF7L2;ARGLU1;COMMD3;SMC2;ZNF740;CHURC1;U...
# Beta-state3 genesdown                  SUMF2;PICALM;MRPS9;ACVR1C;ZNF445;RNF103;PIP4K2...
# Beta-state3 genesup                    CCDC125;ZBED1;DHRSX;ATP5D;ATRNL1;PSPC1;IGSF8;F...
# Beta-state4 genesdown                  ASMTL;CBX3;MAP1B;PINK1;C19orf70;C17orf62;SMDT1...
# Beta-state4 genesup                    N6AMT1;LITAF;POLR1B;RNF146;DCTN5;CACNA2D1;TSPY...
# Beta1                                  SPAG16;C1orf168;KCNA5;NEUROD1;CERKL;EPHX1;MYBP...
# Beta2                                  SUV420H2;AC020922.1;NSF;MICAL3;PTPRH;MCCC2;ETS...
# ND_exocytosis_anticorrelated           CRB3;ANKRD27;ACTL6A;PGP;TPD52L2;TSFM;IFT52;RAB...
# ND_exocytosis_anticorrelated_filtered  SF3B5;TFDP1;ZNF655;TSTA3;CLPP;POLR2G;PNPO;MPHO...
# ND_exocytosis_correlated               C21orf91;KLHDC8A;NALCN;PPP6C;CHCHD10;MRPS18C;D...
# ND_exocytosis_correlated_filtered      PIGP;FKBP2;CYB561;ANKRD17;NCOR2;SURF2;STX12;NU...
# T2D_exocytosis_anticorrelated          SNX7;CYB5R4;AGPS;C8orf59;TSSC4;EMC2;C2orf68;GO...
# T2D_exocytosis_correlated              ZNF141;NR4A2;FOXN2;ENSA;CTSF;RTBDN;C16orf70;AC...
# multi_correlated                       PDK4;GALK2;MAFA;SIN3A;CACNA1C;TRIP12;NPTX2;RAI...
# mutli_anticorrelated                   ADK;COPS3;SCAND1;JTB;SNRPB;SNRNP40;MTHFD2;UGDH...

# %% [markdown]
# ## beta

# %%
gs_res=run_GSEA_gene('beta')
gs_res.res2d.sort_index()
# Out:
# (12988,)
# gene
# SLC2A13   -40.521506
# Name: mlog10P, dtype: float64
# gene
# INS-IGF2    36.40042
# Name: mlog10P, dtype: float64
#                                              es        nes      pval  \
# Term
# Alpha-state 1 down                    -0.159409  -7.575267  0.000000
# Alpha-state 1 up                      -0.176153 -10.402792  0.000000
# Alpha-state 2 down                    -0.197538  -8.136809  0.000000
# Alpha-state 2 up                      -0.133413  -6.143825  0.000000
# Alpha-state 3 down                    -0.246210  -6.955557  0.000000
# Alpha-state 3 up                      -0.138730  -5.493009  0.000000
# Alpha-state 4 down                    -0.208748 -13.179117  0.000000
# Alpha-state 4 up                      -0.160203  -7.640794  0.000000
# Alpha-state 5 down                    -0.141176  -4.702687  0.000000
# Alpha-state 5 up                      -0.165056  -6.945590  0.000000
# Alpha-state 6 down                    -0.138139  -7.344701  0.000000
# Alpha-state 6 up                      -0.194706  -6.841285  0.000000
# Alpha1                                 0.679180   6.578151  0.000000
# Alpha2                                -0.522566 -22.606166  0.000000
# Beta sub1_xin                          0.235203   0.993754  0.447453
# Beta sub2_xin                          0.326498   1.633386  0.038945
# Beta sub3_xin                          0.456934   1.581453  0.051355
# Beta sub4_xin                         -0.232554  -5.066618  0.000000
# Beta-state1 genesdown                 -0.161040  -5.054755  0.000000
# Beta-state1 genesup                   -0.188275 -10.096762  0.000000
# Beta-state2 genesdown                 -0.189732  -7.775977  0.000000
# Beta-state2 genesup                   -0.151921  -5.636200  0.000000
# Beta-state3 genesdown                 -0.185359 -10.780589  0.000000
# Beta-state3 genesup                   -0.170677  -5.722547  0.000000
# Beta-state4 genesdown                 -0.157088  -4.983826  0.000000
# Beta-state4 genesup                   -0.172835  -8.085016  0.000000
# Beta1                                  1.000000  11.043037  0.000000
# Beta2                                 -1.000000 -25.601965  0.000000
# ND_exocytosis_anticorrelated          -0.238606  -3.939880  0.000000
# ND_exocytosis_anticorrelated_filtered -0.251946  -3.678497  0.000000
# ND_exocytosis_correlated              -0.110946  -1.885978  0.010956
# ND_exocytosis_correlated_filtered     -0.076879  -0.995609  0.443254
# T2D_exocytosis_anticorrelated         -0.178139  -3.856312  0.000000
# T2D_exocytosis_correlated             -0.157551  -1.343734  0.133050
# multi_correlated                       0.134546   1.010121  0.418128
# mutli_anticorrelated                  -0.248712  -2.036250  0.003765
#
#                                             fdr  geneset_size  matched_size  \
# Term
# Alpha-state 1 down                     0.000000          2423          1949
# Alpha-state 1 up                       0.000000          4578          3639
# Alpha-state 2 down                     0.000000          1781          1436
# Alpha-state 2 up                       0.000000          2262          1830
# Alpha-state 3 down                     0.000000           821           614
# Alpha-state 3 up                       0.000000          1533          1296
# Alpha-state 4 down                     0.000000          5779          4705
# Alpha-state 4 up                       0.000000          2535          2002
# Alpha-state 5 down                     0.000000          1110           886
# Alpha-state 5 up                       0.000000          1842          1483
# Alpha-state 6 down                     0.000000          3302          2707
# Alpha-state 6 up                       0.000000          1337          1021
# Alpha1                                 0.000000           179            68
# Alpha2                                 0.000000          1967          1575
# Beta sub1_xin                          0.444351            13            12
# Beta sub2_xin                          0.074132            28            17
# Beta sub3_xin                          0.071131            13             8
# Beta sub4_xin                          0.000000           390           355
# Beta-state1 genesdown                  0.000000           981           788
# Beta-state1 genesup                    0.000000          3385          2699
# Beta-state2 genesdown                  0.000000          1784          1409
# Beta-state2 genesup                    0.000000          1397          1114
# Beta-state3 genesdown                  0.000000          4369          3505
# Beta-state3 genesup                    0.000000          1126           912
# Beta-state4 genesdown                  0.000000           989           807
# Beta-state4 genesup                    0.000000          2354          1897
# Beta1                                  0.000000           178            89
# Beta2                                  0.000000           682           501
# ND_exocytosis_anticorrelated           0.000000           250           204
# ND_exocytosis_anticorrelated_filtered  0.000000           191           158
# ND_exocytosis_correlated               0.010840           311           216
# ND_exocytosis_correlated_filtered      0.442553           182           123
# T2D_exocytosis_anticorrelated          0.000000           449           360
# T2D_exocytosis_correlated              0.136959            77            53
# multi_correlated                       0.508330            57            40
# mutli_anticorrelated                   0.004546            54            48
#
#                                                                                    genes  \
# Term
# Alpha-state 1 down                     GPD1L;CRADD;KCNA5;CCDC150;SLC38A4;PRKAB1;PLCL2...
# Alpha-state 1 up                       INS;NPEPL1;G6PC2;DHRS2;IPO13;KCNK17;KLHDC4;MS4...
# Alpha-state 2 down                     INS;KLHDC4;KCNK16;CHGA;ATP1A1;WWC1;REC8;PCSK1N...
# Alpha-state 2 up                       G6PC2;ETFDH;TAF2;SLC38A4;ATP8B1;HADH;BMP5;VPS4...
# Alpha-state 3 down                     PCSK1N;GSTM2;FABP5;RPL3;THAP5;CRYBA2;HIST1H1E;...
# Alpha-state 3 up                       NPEPL1;G6PC2;CRADD;MS4A8;ETFDH;NEUROD1;SLC38A4...
# Alpha-state 4 down                     INS;NPEPL1;G6PC2;DHRS2;IPO13;GPD1L;ETFDH;KCNA5...
# Alpha-state 4 up                       CRADD;MS4A8;TAF2;WWC1;C1orf168;SLC37A3;RBP1;SP...
# Alpha-state 5 down                     INS;NPEPL1;KCNK17;KCNK16;FAM159B;CHGA;C1orf168...
# Alpha-state 5 up                       IPO13;GPD1L;KCNA5;RSAD2;NEUROD1;ATP1A1;SSTR1;S...
# Alpha-state 6 down                     INS;G6PC2;IPO13;KCNK17;GPD1L;ETFDH;KCNA5;ARHGE...
# Alpha-state 6 up                       EHF;CHGA;YTHDC1;HNRNPA1L2;TTLL3;FABP5;FRMD4B;R...
# Alpha1                                 DHRS2;ETFDH;MYBPHL;KCNA5;ARHGEF40;TMEM130;CCDC...
# Alpha2                                 ATP1A1;VPS41;BHLHE40;CTNND2;LPAR6;TTBK1;FER;MR...
# Beta sub1_xin                          PRSS23;SCGB2A1;FFAR4;RBP4;PPP1R1A;SCGN;ASCL2;T...
# Beta sub2_xin                          ID1;RBP1;RGS16;GPX3;FOS;NPY;RASD1;JUNB;ID3;NEN...
# Beta sub3_xin                                      INS;CHGA;ASB9;DLK1;CPE;TIMP1;CKB;CHGB
# Beta sub4_xin                          DNAJB9;ID2;COPZ1;BRIX1;HSPD1;HSPE1;SAP18;MRPL1...
# Beta-state1 genesdown                  G6PC2;ETFDH;TFDP1;RRM1;RPL3;MMRN1;DNAJB9;SMAD9...
# Beta-state1 genesup                    INS;NPEPL1;DHRS2;ID1;IPO13;KCNK17;GPD1L;KLHDC4...
# Beta-state2 genesdown                  CASR;IPO13;KLHDC4;ENTPD3;FAM159B;CHGA;C10orf10...
# Beta-state2 genesup                    ETFDH;SLC25A34;BMP5;VPS41;PDE6B;NECAB1;BHLHE40...
# Beta-state3 genesdown                  CASR;G6PC2;DHRS2;ID1;GPD1L;KCNK16;ETFDH;TAF2;N...
# Beta-state3 genesup                    IPO13;KCNA5;SCTR;PRKAB1;DUSP26;DPY19L2;RPL3;KL...
# Beta-state4 genesdown                  INS;ID1;FAM159B;SAMD11;YTHDC1;PCSK1N;RBP1;GSTM...
# Beta-state4 genesup                    CASR;G6PC2;DHRS2;IPO13;ENTPD3;KCNA5;NEUROD1;SL...
# Beta1                                  INS-IGF2;INS;CASR;NPEPL1;G6PC2;DHRS2;ID1;XIRP2...
# Beta2                                  PTPRN;SERTAD4;SIN3A;PRPSAP1;TYRO3;WDR1;RAB40C;...
# ND_exocytosis_anticorrelated           PSPH;TFDP1;PDCD10;ID2;C14orf166;PCGF3;NDUFS2;A...
# ND_exocytosis_anticorrelated_filtered  PSPH;TFDP1;PDCD10;ID2;C14orf166;PCGF3;NDUFS2;A...
# ND_exocytosis_correlated               INS;FAM159B;SLC37A3;BMP5;RBP1;KCNH2;TCF20;HERC...
# ND_exocytosis_correlated_filtered      INS;FAM159B;BMP5;RBP1;KCNH2;HERC2;GPX3;GSTK1;T...
# T2D_exocytosis_anticorrelated          C10orf10;CAPS;TFDP1;THAP5;PRPF6;CBR1;COX7C;APH...
# T2D_exocytosis_correlated              CHGA;SCGB2A1;CST3;DLK1;MYO5C;RNF146;SMPDL3B;AN...
# multi_correlated                       FAM159B;CHGA;BMP5;KCNH2;GPX3;GSTK1;DMKN;MRAP2;...
# mutli_anticorrelated                   ID2;RBP4;H1F0;MAGEH1;SNF8;SLC25A6;PSMB7;STK25;...
#
#                                                                              ledge_genes
# Term
# Alpha-state 1 down                     EI24;DPH5;MTF2;SMARCA5;HMGN3;MTMR6;BLZF1;TARS;...
# Alpha-state 1 up                       PGAP3;THYN1;HNF4A;MRPL1;C15orf48;CKAP4;EMC10;C...
# Alpha-state 2 down                     EIF4EBP1;MAP1S;CYB5R3;CREB3L2;SRPR;FOXRED1;EMD...
# Alpha-state 2 up                       AKAP11;FAM98A;MTMR11;TTF1;C7orf55;TOMM5;LETM1;...
# Alpha-state 3 down                     USP34;DNAL1;CNOT4;VCPIP1;LATS1;HLF;ZNF525;SLC8...
# Alpha-state 3 up                       CSTB;MCOLN1;EIF6;WDR83OS;TMEM60;UBE2V2;LRPAP1;...
# Alpha-state 4 down                     COX6B1;LETM1;WASL;SLC38A2;ARL5A;ATP5SL;CEP44;F...
# Alpha-state 4 up                       CSTF3;FAM175B;NOP16;SYNCRIP;ZNF506;PGRMC1;THEM...
# Alpha-state 5 down                     FTH1;WTAP;CSTB;MCOLN1;EIF6;WDR83OS;LRPAP1;ECHS...
# Alpha-state 5 up                       IRF6;MAP2K4;TWSG1;CNOT8;IFT57;COX10;NOLC1;DHX1...
# Alpha-state 6 down                     GUCY1B3;TMEM106C;CPSF3;RRNAD1;FKBP11;RAP1GAP2;...
# Alpha-state 6 up                       HLA-A;USP15;DDX39A;BCAP29;BCAM;MAN2B2;CHMP1B;E...
# Alpha1                                 DHRS2;ETFDH;MYBPHL;KCNA5;ARHGEF40;TMEM130;CCDC...
# Alpha2                                 CKB;ZNF852;ZFAND2A;PMPCA;SDCCAG3;PIP5K1C;SET;C...
# Beta sub1_xin                                     PRSS23;SCGB2A1;FFAR4;RBP4;PPP1R1A;SCGN
# Beta sub2_xin                          ID1;RBP1;RGS16;GPX3;FOS;NPY;RASD1;JUNB;ID3;NEN...
# Beta sub3_xin                                                         INS;CHGA;ASB9;DLK1
# Beta sub4_xin                          PSMD8;RPS27L;CHCHD10;TERF2IP;RPF2;ARPC5L;CHMP2...
# Beta-state1 genesdown                  TMEM183A;JKAMP;RPL41;DCTN5;TARBP1;ADAM9;IPO9;P...
# Beta-state1 genesup                    TSPAN17;ZCCHC18;OLFM2;ADCK5;CXorf38;MAP2K7;RPL...
# Beta-state2 genesdown                  MAP1S;CYB5R3;CREB3L2;SRPR;EMD;ARF5;PSMB1;UBE2D...
# Beta-state2 genesup                    C7orf55;TOMM5;LETM1;CEP44;RAB22A;ARGLU1;ATP5C1...
# Beta-state3 genesdown                  PSMC5;FTSJ3;ING4;ORAI3;DPH5;SMARCA5;BLZF1;USP1...
# Beta-state3 genesup                    OXA1L;FKBP11;PDHB;SP100;RPSAP58;GAK;AP3S1;BMS1...
# Beta-state4 genesdown                  FAM200B;RPL14;PAFAH1B2;IGFBP5;EMP2;KCNQ2;PTPRS...
# Beta-state4 genesup                    ENAM;FKBP4;PTTG1IP;SCRN3;HID1;PDP1;CDK16;C4orf...
# Beta1                                  INS-IGF2;INS;CASR;NPEPL1;G6PC2;DHRS2;ID1;XIRP2...
# Beta2                                  PTPRN;SERTAD4;SIN3A;PRPSAP1;TYRO3;WDR1;RAB40C;...
# ND_exocytosis_anticorrelated           ST13;RPL24;POLR2G;TKT;MRPL9;MORF4L1;MRPS18B;LO...
# ND_exocytosis_anticorrelated_filtered  ST13;RPL24;POLR2G;TKT;MRPL9;MORF4L1;MRPS18B;LO...
# ND_exocytosis_correlated               ZNF248;NDUFC2;KLF3;LUC7L3;LSAMP;TPPP;AMACR;SER...
# ND_exocytosis_correlated_filtered      MEST;RGS9;YWHAG;NDFIP2;GSTA4;C1QL1;ABCA2;SIK2;...
# T2D_exocytosis_anticorrelated          FUNDC1;NIF3L1;SRRT;C8orf59;CSTB;EIF6;CHD1;UBE2...
# T2D_exocytosis_correlated              POLR3C;ZNF141;WBP1L;SS18L2;CABP7;CTSF;SFSWAP;M...
# multi_correlated                       FAM159B;CHGA;BMP5;KCNH2;GPX3;GSTK1;DMKN;MRAP2;...
# mutli_anticorrelated                   ADSL;CTSB;CHCHD7;EIF4EBP1;DNAJC8;LMBRD2;PCGF1;...

# %% [markdown]
# ## delta

# %% [markdown]
# gs_res_d=run_GSEA_gene('delta')
# gs_res_d.res2d.sort_index()

# %% [markdown]
# ### Save results

# %%
gs_res.res2d[['es','nes','pval','fdr','geneset_size','matched_size','ledge_genes']].to_csv('../dat/figdata/GSEA_beta_all_seed1000_p10000_noweight.csv')
gs_res_a.res2d[['es','nes','pval','fdr','geneset_size','matched_size','ledge_genes']].to_csv('../dat/figdata/GSEA_alpha_all_seed1000_p10000_noweight.csv')
#gs_res_d.res2d[['es','nes','pval','fdr','geneset_size','matched_size']].to_csv('../dat/figdata/GSEA_delta_all_seed1000_p10000_noweight.csv')

from gseapy.plot import gseaplot, heatmap
terms = gs_res.res2d.index 
for i in range(len(terms)):
    gseaplot(gs_res.ranking, term=terms[i], **gs_res.results[terms[i]],ofname=terms[i]+'_beta_all_seed1000_p10000_noweight.pdf')
terms = gs_res_a.res2d.index 
for i in range(len(terms)):
    gseaplot(gs_res_a.ranking, term=terms[i], **gs_res_a.results[terms[i]],ofname=terms[i]+'_all_seed1000_p10000_noweight.pdf')
#terms = gs_res_d.res2d.index 
#for i in range(len(terms)):
#    gseaplot(gs_res_d.ranking, term=terms[i], **gs_res_d.results[terms[i]],ofname=terms[i]+'_delta_all_seed1000_p10000_noweight.pdf')
