# %% [markdown]
# # Perform GSEA using GSEAPY
#
# Following the potocol defined here: https://gseapy.readthedocs.io/en/latest/gseapy_tutorial.html#use-gsea-command-or-gsea

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina' # mac
import pandas as pd
import gseapy as gp
import numpy as np
import matplotlib.pyplot as plt

# %%
gp.__version__
# Out:
# '0.9.9'

# %% [markdown]
# ## alpha

# %%
gene_exp_alpha = pd.read_csv("../dat/figdata/fig2_prom_ttest_res.csv",index_col=1)
#gene_exp_alpha.head()
df = gene_exp_alpha.loc[gene_exp_alpha["celltype"]=="alpha"].sort_values(by='odds', ascending=False)["odds"]
df=np.log2(df)

# replace inf to max exclude inf
#df=df.replace(np.inf,df[~df.isin([np.inf])].max(0))
#df=df.replace(-np.inf,df[~df.isin([-np.inf])].min(0))
df.to_csv('../dat/figdata/res.genes.a.rnk',sep='\t')
rnk = pd.read_table("../dat/figdata/res.genes.a.rnk", header=None)

for i in  rnk.index[(rnk[1]==np.inf).tolist()].tolist():
    rnk.iloc[i,1]= df[~df.isin([np.inf])].max(0)*(1+np.random.uniform()/100)

for i in  rnk.index[(rnk[1]==-np.inf).tolist()].tolist():
    rnk.iloc[i,1]= df[~df.isin([-np.inf])].min(0)*(1+np.random.uniform()/100)

#rnk.set_index(0)
#rnk.head()

# run gsea
# enrichr libraries are supported by gsea module. Just provide the name

gs_res_a = gp.prerank(rnk=rnk, # or data='./P53_resampling_data.txt'
                 gene_sets='../dat/glists/gsea_go.gmt', # enrichr library names or gmt file
                 #set permutation_type to phenotype if samples >=15
                 permutation_num=1000, # reduce number to speed up test
                 outdir=None,  # do not write output to disk
                 no_plot=True, # Skip plotting
                 #weighted_score_type=1,
                 #ascending=False,
                    seed=1000,
                 min_size=1,
                 max_size=2100,
                 processes=4)
                 #format='png')
gs_res_a.res2d
# Out:
# 2019-03-12 15:13:21,277 Input gene rankings contains duplicated IDs, Only use the duplicated ID with highest value!
#                   es       nes      pval       fdr  geneset_size  \
# Term
# GO_0090276  0.407599  1.325729  0.097911  0.197442            73
# GO_0080135 -0.248129 -1.102971  0.250000  0.276551           104
# GO_0034976  0.303437  1.056027  0.355311  0.385044           106
# GO_0036003 -0.364942 -1.152870  0.257979  0.429022            29
#
#             matched_size                                              genes  \
# Term
# GO_0090276            64  PAX8;ABCC8;GCG;GCK;SYT7;G6PC2;ITPR1;MTNR1B;KCN...
# GO_0080135            99  CREBBP;MTOR;CAMK2G;NUP35;NUP188;CRHBP;DNAJB6;R...
# GO_0034976            97  THBS1;TMEM117;ERN2;MBTPS1;UBXN6;ANKS4B;ITPR1;C...
# GO_0036003            24  CHD6;CREB3L1;VEGFA;RBPJ;MT3;HIF1A;HSF4;HSF5;NF...
#
#                                                   ledge_genes
# Term
# GO_0090276  PAX8;ABCC8;GCG;GCK;SYT7;G6PC2;ITPR1;MTNR1B;KCN...
# GO_0080135  DNAJC2;AAAS;CAMK2B;BAG2;ATM;HSPA8;ATR;BAG4;NUP...
# GO_0034976  THBS1;TMEM117;ERN2;MBTPS1;UBXN6;ANKS4B;ITPR1;C...
# GO_0036003              DDIT3;ATF4;CEBPB;HSF1;SESN2;KLF2;ATF3

# %% [markdown]
# ## beta

# %%
gene_exp_alpha = pd.read_csv("../dat/figdata/fig2_prom_ttest_res.csv",index_col=1)
#gene_exp_alpha.head()
df = gene_exp_alpha.loc[gene_exp_alpha["celltype"]=="beta"].sort_values(by='odds', ascending=False)["odds"]
df=np.log2(df)

# replace inf to max exclude inf
#df=df.replace(np.inf,df[~df.isin([np.inf])].max(0))
#df=df.replace(-np.inf,df[~df.isin([-np.inf])].min(0))
df.to_csv('../dat/figdata/res.genes.a.rnk',sep='\t')
rnk = pd.read_table("../dat/figdata/res.genes.a.rnk", header=None)

for i in  rnk.index[(rnk[1]==np.inf).tolist()].tolist():
    rnk.iloc[i,1]= df[~df.isin([np.inf])].max(0)*(1+np.random.uniform()/100)

for i in  rnk.index[(rnk[1]==-np.inf).tolist()].tolist():
    rnk.iloc[i,1]= df[~df.isin([-np.inf])].min(0)*(1+np.random.uniform()/100)

#rnk.set_index(0)
#rnk.head()


# run gsea
# enrichr libraries are supported by gsea module. Just provide the name

gs_res = gp.prerank(rnk=rnk, # or data='./P53_resampling_data.txt'
                 gene_sets='../dat/glists/gsea_go.gmt', # enrichr library names or gmt file
                 #set permutation_type to phenotype if samples >=15
                 permutation_num=1000, # reduce number to speed up test
                 outdir=None,  # do not write output to disk
                 no_plot=True, # Skip plotting
                 #weighted_score_type=1,
                 #ascending=False,
                    seed=1000,
                 min_size=10,
                 max_size=2100,
                 processes=8)
                 #format='png')
gs_res.res2d
# Out:
# 2019-03-12 15:13:31,549 Input gene rankings contains duplicated IDs, Only use the duplicated ID with highest value!
#                   es       nes      pval       fdr  geneset_size  \
# Term
# GO_0090276  0.563350  1.714387  0.001152  0.002314            73
# GO_0036003 -0.403938 -1.313761  0.134615  0.184162            29
# GO_0080135 -0.250025 -1.064758  0.320988  0.314917           104
# GO_0034976  0.312210  0.989914  0.500000  0.498120           106
#
#             matched_size                                              genes  \
# Term
# GO_0090276            60  RFX3;INS;ABCC8;RAPGEF4;ADRA2C;RAPGEF3;GRP;G6PC...
# GO_0036003            24  HSF5;MT3;CHD6;CREB3L1;TP53;HSF1;ATF6B;HSF2;NFE...
# GO_0080135            99  NUP93;NUP35;CAMK2G;DNAJB6;HSPB8;CREBBP;CRHBP;U...
# GO_0034976            96  THBS1;AMFR;BRSK2;RHBDD1;TXNDC11;UBXN6;MBTPS1;B...
#
#                                                   ledge_genes
# Term
# GO_0090276  RFX3;INS;ABCC8;RAPGEF4;ADRA2C;RAPGEF3;GRP;G6PC...
# GO_0036003           MBTPS2;ATF3;HSPA5;ATF4;CEBPB;DDIT3;SESN2
# GO_0080135  HSPA1A;HSPA1L;NUP85;GSK3B;NUP214;MLST8;NEK4;BA...
# GO_0034976  THBS1;AMFR;BRSK2;RHBDD1;TXNDC11;UBXN6;MBTPS1;B...

# %% [markdown]
# ### Save results

# %%
gs_res.res2d[['es','nes','pval','fdr']].to_csv('../dat/figdata/GSEA_beta_GO_seed1000.csv')
gs_res_a.res2d[['es','nes','pval','fdr']].to_csv('../dat/figdata/GSEA_alpha_GO_seed1000.csv')

from gseapy.plot import gseaplot, heatmap
terms = gs_res.res2d.index 
for i in range(len(terms)):
    gseaplot(gs_res.ranking, term=terms[i], **gs_res.results[terms[i]],ofname=terms[i]+'_go_b_seed1000.pdf')
terms = gs_res_a.res2d.index 
for i in range(len(terms)):
    gseaplot(gs_res_a.ranking, term=terms[i], **gs_res_a.results[terms[i]],ofname=terms[i]+'_go_a_seed1000.pdf')
