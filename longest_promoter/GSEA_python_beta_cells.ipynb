# %% [markdown]
# # Perform GSEA using GSEAPY
#
# Following the potocol defined here: https://gseapy.readthedocs.io/en/latest/gseapy_tutorial.html#use-gsea-command-or-gsea

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina' # mac
import pandas as pd
import gseapy as gp
import matplotlib.pyplot as plt

# %%
gp.__version__
# Out:
# '0.9.9'

# %% [markdown]
# ## 1. Prepare expression file
# In our case, the expression file is the percentage of cells inside each pseudostate **bin**

# %%
gene_exp = pd.read_table("./dat/beta.100_bin_pseudotime_raw.promoter.txt").transpose()
gene_exp.head()
# Out:
#           0    1         2         3         4         5         6         7   \
# SAMD11   0.0  0.0  0.000000  2.857143  1.162791  1.047120  0.613497  1.441441
# NOC2L    0.0  0.0  6.666667  5.714286  2.325581  3.664921  2.453988  3.603604
# KLHL17   0.0  0.0  0.000000  2.857143  2.325581  1.570681  0.920245  0.900901
# PLEKHN1  0.0  0.0  0.000000  0.000000  1.162791  1.047120  0.306748  1.981982
# HES4     0.0  0.0  0.000000  2.857143  2.325581  2.617801  1.533742  1.261261
#
#                8         9  ...         90   91        92        93        94  \
# SAMD11   0.000000  2.040816 ...   0.416667  0.5  3.875969  1.204819  0.000000
# NOC2L    1.010101  2.040816 ...   2.500000  3.0  3.875969  3.614458  6.896552
# KLHL17   2.020202  2.040816 ...   0.416667  1.0  1.550388  0.000000  1.724138
# PLEKHN1  2.020202  2.040816 ...   2.500000  4.0  2.325581  0.000000  5.172414
# HES4     2.020202  0.000000 ...   1.250000  2.5  3.100775  4.819277  1.724138
#
#             95        96    97    98   99
# SAMD11   0.000  0.000000   0.0   0.0  0.0
# NOC2L    9.375  9.090909   0.0  20.0  0.0
# KLHL17   3.125  4.545455   0.0   0.0  0.0
# PLEKHN1  0.000  4.545455   0.0   0.0  0.0
# HES4     0.000  4.545455  10.0   0.0  0.0
#
# [5 rows x 100 columns]

# %% [markdown]
# ## 2. Phenotype file (.cls)
# - The first line specify the total samples and phenotype numbers. Leave number 1 alway be 1.
# - The second line specify the phenotype class(name).
# - The third line specify column attributes in setp 1.

# %%
threshold=round((10.3107-9.39)/(11.27-9.39)*100)
threshold
# Out:
# 49

# %%
with open('./dat/pheno_beta.cls',"w") as f:
    f.write("100 2 1\n")
    f.write("#B1 B2\n")
    f.write("B1 "*threshold+("B2 "*(100-threshold)).rstrip()+"\n")

# %%
phenoA, phenoB, class_vector =  gp.parser.gsea_cls_parser("./dat/pheno_beta.cls")
#class_vector used to indicate group attributes for each sample
print(class_vector)
# Out:
# ['B1', 'B1', 'B1', 'B1', 'B1', 'B1', 'B1', 'B1', 'B1', 'B1', 'B1', 'B1', 'B1', 'B1', 'B1', 'B1', 'B1', 'B1', 'B1', 'B1', 'B1', 'B1', 'B1', 'B1', 'B1', 'B1', 'B1', 'B1', 'B1', 'B1', 'B1', 'B1', 'B1', 'B1', 'B1', 'B1', 'B1', 'B1', 'B1', 'B1', 'B1', 'B1', 'B1', 'B1', 'B1', 'B1', 'B1', 'B1', 'B1', 'B2', 'B2', 'B2', 'B2', 'B2', 'B2', 'B2', 'B2', 'B2', 'B2', 'B2', 'B2', 'B2', 'B2', 'B2', 'B2', 'B2', 'B2', 'B2', 'B2', 'B2', 'B2', 'B2', 'B2', 'B2', 'B2', 'B2', 'B2', 'B2', 'B2', 'B2', 'B2', 'B2', 'B2', 'B2', 'B2', 'B2', 'B2', 'B2', 'B2', 'B2', 'B2', 'B2', 'B2', 'B2', 'B2', 'B2', 'B2', 'B2', 'B2', 'B2']

# %%
print("positively correlated: ", phenoA)
# Out:
# positively correlated:  B1

# %%
print("negtively correlated: ", phenoB)
# Out:
# negtively correlated:  B2

# %% [markdown]
# ## 3. define gene sets
#
# In our case, we will use the beta gene sets from the three literature. And save to [gmt](http://software.broadinstitute.org/cancer/software/gsea/wiki/index.php/Data_formats#GMT:_Gene_Matrix_Transposed_file_format_.28.2A.gmt.29) format.
#
# It was done in another [notebook](./compare_with_previous_glists.ipynb)

# %% [markdown]
# ## 4. Run gsea
# The result is look like this:
#
# ![The result interpetation](https://software.broadinstitute.org/gsea/doc/ug_images/anl-enrichment-geneset-plot-annotated.gif)
#
# see also https://software.broadinstitute.org/gsea/doc/GSEAUserGuideFrame.html
#
# - Normalized Enrichment Score (NES)=$\frac{\textrm{actual ES}}{\textrm{mean ES against all permutations}}$

# %%
# run gsea
# enrichr libraries are supported by gsea module. Just provide the name

gs_res = gp.gsea(data=gene_exp, # or data='./P53_resampling_data.txt'
                 gene_sets='./dat/glists/gsea.gmt', # enrichr library names or gmt file
                 cls= class_vector, # cls=class_vector
                 #set permutation_type to phenotype if samples >=15
                 permutation_type='phenotype',
                 permutation_num=100, # reduce number to speed up test
                 outdir=None,  # do not write output to disk
                 no_plot=True, # Skip plotting
                 method='signal_to_noise',
                 processes=4,
                 min_size=0,
                # seed=321,
                 max_size=4000,
                 format='png')

# %%
#access the dataframe results throught res2d attribute
gs_res.res2d
# Out:
#                         es       nes      pval       fdr  geneset_size  \
# Term
# A1_alpha          0.622584  2.524433  0.000000  0.000000           240
# A2_alpha         -0.557401 -2.709127  0.000000  0.000000          3526
# B1_beta           0.994000  2.728765  0.000000  0.000000            75
# B2_beta          -0.990073 -3.501445  0.000000  0.000000           420
# Beta sub4_xin    -0.422557 -1.991242  0.000000  0.000000           390
# immature_bader   -0.381203 -1.724829  0.000000  0.000000           579
# Beta sub1_xin     0.579981  1.515629  0.000000  0.076336            13
# ST8SIA1+_dorrell  0.376907  1.406121  0.000000  0.137405            46
# Beta sub2_xin     0.435350  1.413928  0.000000  0.171756            28
# Beta sub3_xin     0.516229  1.135504  0.272727  0.496183            13
# CD9+_dorrell      0.257191  0.953346  0.600000  0.559796            45
# mature_bader      0.281857  1.012793  0.571429  0.591603            72
# CD9-_dorrell      0.356435  1.083824  0.400000  0.599782            57
# ST8SIA1-_dorrell  0.238942  0.802630  0.666667  0.717557            65
#
#                   matched_size  \
# Term
# A1_alpha                   239
# A2_alpha                  3526
# B1_beta                     75
# B2_beta                    420
# Beta sub4_xin              323
# immature_bader             441
# Beta sub1_xin               11
# ST8SIA1+_dorrell            34
# Beta sub2_xin               25
# Beta sub3_xin                8
# CD9+_dorrell                34
# mature_bader                42
# CD9-_dorrell                48
# ST8SIA1-_dorrell            55
#
#                                                               genes  \
# Term
# A1_alpha          G6PC2;MS4A8;IGFBP1;GRIK1;NEUROD1;NKAIN3;DNAH12...
# A2_alpha          FFAR4;C5orf49;HECW2;CDKN1A;XKR9;NPM2;TRIM67;CM...
# B1_beta           G6PC2;MYLK3;INS-IGF2;MS4A8;KCNK17;IGFBP1;SPON2...
# B2_beta           SERPINE2;TM9SF2;FARP2;SHQ1;PHF1;POLM;ACAD11;AR...
# Beta sub4_xin     CCT6A;TMSB4X;PSMF1;COPZ1;SSR3;DNAJB9;CHCHD2;HS...
# immature_bader    G6PC2;GCK;NELL1;BCKDK;PSMF1;SERPINA10;GPC4;HSB...
# Beta sub1_xin     FFAR4;SCGB2A1;RBP4;FXYD2;PRSS23;TUBA4A;TUBB2A;...
# ST8SIA1+_dorrell  ATP8B1;MYOM1;TP53I11;TMEM130;SMOC1;TFF3;GPX3;N...
# Beta sub2_xin     ID1;NPY;STMN2;TFF3;RGS16;JUNB;RBP1;SEC11C;GPX3...
# Beta sub3_xin            DLK1;CHGA;IGFBP7;ASB9;LAMP1;TIMP1;CKB;CHGB
# CD9+_dorrell      MIA2;KCNA5;GNAL;TACSTD2;RBP4;PRDM1;TFPI;TSPAN3...
# mature_bader      NEB;TRIM67;ZNF804A;WNT5B;SVEP1;GPR83;SYT1;NPFF...
# CD9-_dorrell      CCDC81;ADAMTS5;ITM2A;ZNF804A;NPY;COL24A1;PCDH7...
# ST8SIA1-_dorrell  G6PC2;NEUROD1;SLC27A2;RRAS2;SCGB2A1;MARS2;OXCT...
#
#                                                         ledge_genes
# Term
# A1_alpha          G6PC2;MS4A8;IGFBP1;GRIK1;NEUROD1;NKAIN3;DNAH12...
# A2_alpha          SMARCC1;ARHGAP12;TBKBP1;PPP6R1;FAM126B;RFPL2;S...
# B1_beta           G6PC2;MYLK3;INS-IGF2;MS4A8;KCNK17;IGFBP1;SPON2...
# B2_beta           SERPINE2;TM9SF2;FARP2;SHQ1;PHF1;POLM;ACAD11;AR...
# Beta sub4_xin     RABGGTB;PITHD1;HLA-E;EMC7;CYSTM1;EIF5;NOP10;CR...
# immature_bader    SCD;C9orf64;RGS11;ISCA2;CLN6;ATOX1;FBXO2;CNPY3...
# Beta sub1_xin                                    FFAR4;SCGB2A1;RBP4
# ST8SIA1+_dorrell  ATP8B1;MYOM1;TP53I11;TMEM130;SMOC1;TFF3;GPX3;N...
# Beta sub2_xin        ID1;NPY;STMN2;TFF3;RGS16;JUNB;RBP1;SEC11C;GPX3
# Beta sub3_xin                                 DLK1;CHGA;IGFBP7;ASB9
# CD9+_dorrell                MIA2;KCNA5;GNAL;TACSTD2;RBP4;PRDM1;TFPI
# mature_bader      NEB;TRIM67;ZNF804A;WNT5B;SVEP1;GPR83;SYT1;NPFF...
# CD9-_dorrell      CCDC81;ADAMTS5;ITM2A;ZNF804A;NPY;COL24A1;PCDH7...
# ST8SIA1-_dorrell    G6PC2;NEUROD1;SLC27A2;RRAS2;SCGB2A1;MARS2;OXCT1

# %% [markdown]
# ### show the results
# The **gsea** module will generate heatmap for genes in each gene sets in the backgroud.
# But if you need to do it yourself, use the code below

# %%
from gseapy.plot import gseaplot, heatmap
terms = gs_res.res2d.index
for i in range(len(terms)):
    gseaplot(gs_res.ranking, term=terms[i], **gs_res.results[terms[i]])

# %%
for i in range(len(terms)):
    gseaplot(gs_res.ranking, term=terms[i], **gs_res.results[terms[i]],ofname=terms[i]+'_beta.png')
