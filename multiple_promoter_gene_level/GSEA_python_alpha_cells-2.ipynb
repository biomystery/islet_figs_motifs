# %% [markdown]
# # Perform GSEA using GSEAPY
#
# Following the potocol defined here: https://gseapy.readthedocs.io/en/latest/gseapy_tutorial.html#use-gsea-command-or-gsea

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina' # mac
import pandas as pd
import gseapy as gp
import matplotlib.pyplot as plt

# %%
gp.__version__
# Out:
# '0.9.9'

# %% [markdown]
# ## 1. Prepare prerank file
#
# * eg: https://github.com/zqfang/GSEApy/blob/master/tests/data/temp.rnk

# %%
gene_exp_alpha = pd.read_csv("./dat/1901/res.genes_level.a.csv",index_col=0)
gene_exp_alpha.head()
# Out:
#               pval      odds  type1_frac  type2_frac       FDR  \
# SAMD11    0.000002  0.532730    0.039850    0.072289  0.000013
# NOC2L     0.193454  0.872666    0.040319    0.045934  0.245128
# KLHL17    0.249872  0.827881    0.013127    0.015813  0.299613
# PLEKHN1   0.000105  0.439710    0.013127    0.029367  0.000419
# C1orf170  0.291157  1.227541    0.013830    0.011295  0.338060
#
#           padj.Bonferroni    FDR.BY
# SAMD11           0.030243  0.000137
# NOC2L            1.000000  1.000000
# KLHL17           1.000000  1.000000
# PLEKHN1          1.000000  0.004283
# C1orf170         1.000000  1.000000

# %%
df = gene_exp_alpha.sort_values(by='odds', ascending=False)["odds"]

# replace inf to max exclude inf
df.replace(np.inf,df[~df.isin([np.inf])].max(0)).to_csv('./dat/1901/res.genes.a.rnk',sep='\t')

# %% [markdown]
# ## 2. define gene sets
#
# In our case, we will use the beta gene sets from the three literature. And save to [gmt](http://software.broadinstitute.org/cancer/software/gsea/wiki/index.php/Data_formats#GMT:_Gene_Matrix_Transposed_file_format_.28.2A.gmt.29) format.
#
# It was done in another [notebook](./compare_with_previous_glists.ipynb)

# %% [markdown]
# ## 3. Run gsea
#
# ```python
# gseapy.prerank(rnk='gsea_data.rnk', gene_sets='ene_sets.gmt', outdir='gseapy_out', min_size=15,
#                max_size=1000, permutation_n=1000, weighted_score_type=1, ascending=False,
#                figsize=(6.5,6), format='png')
# ```

# %%
# run gsea
# enrichr libraries are supported by gsea module. Just provide the name

gs_res = gp.prerank(rnk='./dat/1901/res.genes.a.rnk', # or data='./P53_resampling_data.txt'
                 gene_sets='./dat/glists/gsea.gmt', # enrichr library names or gmt file
                 #set permutation_type to phenotype if samples >=15
                 permutation_num=1000, # reduce number to speed up test
                 outdir=None,  # do not write output to disk
                 no_plot=True, # Skip plotting
                 weighted_score_type=1,
                 ascending=False,
                 min_size=0,
                 max_size=4000,
                 processes=4,
                 format='png')

# %%
#access the dataframe results throught res2d attribute
gs_res.res2d
# Out:
#                         es       nes      pval           fdr  geneset_size  \
# Term
# A1_alpha          0.793763  3.526346  0.000000  0.000000e+00           240
# B1_beta           0.672698  2.728089  0.000000  0.000000e+00            75
# CD9-_dorrell      0.375997  1.468218  0.157042  2.525490e-01            57
# ST8SIA1+_dorrell  0.363038  1.389380  0.155419  2.532741e-01            46
# Beta sub3_xin     0.451421  1.238652  0.217005  3.504255e-01            13
# Beta sub1_xin     0.525961  1.590612  0.070358  4.666667e-01            13
# mature_bader      0.270470  1.046510  0.354675  5.584577e-01            72
# CD9+_dorrell      0.269371  1.065961  0.331617  5.820385e-01            45
# Beta sub2_xin     0.278770  0.991437  0.414737  6.252608e-01            28
# ST8SIA1-_dorrell  0.217337  0.874103  0.551308  6.332223e-01            65
# immature_bader    0.070001  0.319919  1.000000  9.978542e-01           579
# A2_alpha         -0.442776       NaN       NaN  1.000000e+09          3526
# B2_beta          -0.352978       NaN       NaN  1.000000e+09           420
# Beta sub4_xin    -0.092511       NaN       NaN  1.000000e+09           390
#
#                   matched_size  \
# Term
# A1_alpha                   240
# B1_beta                     75
# CD9-_dorrell                55
# ST8SIA1+_dorrell            45
# Beta sub3_xin                9
# Beta sub1_xin               13
# mature_bader                51
# CD9+_dorrell                41
# Beta sub2_xin               28
# ST8SIA1-_dorrell            64
# immature_bader             563
# A2_alpha                  3524
# B2_beta                    420
# Beta sub4_xin              386
#
#                                                               genes  \
# Term
# A1_alpha          RAC2;RNF17;GPR37L1;PGAM2;GALNT15;HTR1F;MS4A8;O...
# B1_beta           MS4A8;PDE6C;IGFBP1;FREM3;G6PC2;GRIK1;SLC25A34;...
# CD9-_dorrell      IGSF1;CCDC81;LRRTM4;ADAMTS5;NAV3;SEMA6A;NPY;GR...
# ST8SIA1+_dorrell  TFF3;MYOM1;TP53I11;KIRREL3;ATP8B1;TMEM130;ST8S...
# Beta sub3_xin         CHGA;ASB9;IGFBP7;CPE;INS;TIMP1;LAMP1;CHGB;CKB
# Beta sub1_xin     RBP4;SCGB2A1;PPP1R1A;FFAR4;SCGN;PRSS23;FXYD2;T...
# mature_bader      TNS1;NPFFR2;SVEP1;NUP210L;RHOH;ITGA9;GPR83;APO...
# CD9+_dorrell      KCNA5;RBP4;PPP1R1A;AK5;ZFP36;PRDM1;NPC1L1;MIA2...
# Beta sub2_xin     TFF3;NPY;IAPP;RBP1;IGFBP5;PAM;GPX3;PEMT;ID1;SE...
# ST8SIA1-_dorrell  G6PC2;SLC5A1;SCGB2A1;NEUROD1;RFX6;SLC27A2;LIN7...
# immature_bader    GPC4;LOXL2;G6PC2;ARHGDIG;SERPINA10;SV2A;GCK;NE...
# A2_alpha          BOC;FHOD3;TMEM130;FFAR4;CORO2B;PXN;ABLIM2;SLC3...
# B2_beta           PLA2G6;ADCYAP1;TTF2;COX20;SLC7A11;C5orf24;TRMT...
# Beta sub4_xin     MMP7;GCG;AUP1;GDF15;HIST1H1C;LURAP1L;DNAJC12;T...
#
#                                                         ledge_genes
# Term
# A1_alpha          RAC2;RNF17;GPR37L1;PGAM2;GALNT15;HTR1F;MS4A8;O...
# B1_beta           MS4A8;PDE6C;IGFBP1;FREM3;G6PC2;GRIK1;SLC25A34;...
# CD9-_dorrell      IGSF1;CCDC81;LRRTM4;ADAMTS5;NAV3;SEMA6A;NPY;GR...
# ST8SIA1+_dorrell  TFF3;MYOM1;TP53I11;KIRREL3;ATP8B1;TMEM130;ST8S...
# Beta sub3_xin                        CHGA;ASB9;IGFBP7;CPE;INS;TIMP1
# Beta sub1_xin                       RBP4;SCGB2A1;PPP1R1A;FFAR4;SCGN
# mature_bader      TNS1;NPFFR2;SVEP1;NUP210L;RHOH;ITGA9;GPR83;APO...
# CD9+_dorrell      KCNA5;RBP4;PPP1R1A;AK5;ZFP36;PRDM1;NPC1L1;MIA2...
# Beta sub2_xin     TFF3;NPY;IAPP;RBP1;IGFBP5;PAM;GPX3;PEMT;ID1;SE...
# ST8SIA1-_dorrell  G6PC2;SLC5A1;SCGB2A1;NEUROD1;RFX6;SLC27A2;LIN7...
# immature_bader    GPC4;LOXL2;G6PC2;ARHGDIG;SERPINA10;SV2A;GCK;NE...
# A2_alpha          FGFR1OP;GULP1;FHL1;RIC8B;MON1A;FAM53A;KAT6B;CC...
# B2_beta           JUN;UNC13B;RAB11FIP3;TRPC4AP;DNM2;POLM;TCEANC2...
# Beta sub4_xin     SST;MRPL18;TCP1;EIF4EBP1;SUCLG1;ZNF622;NR0B1;E...

# %% [markdown]
# ### show the results
# The **gsea** module will generate heatmap for genes in each gene sets in the backgroud.
# But if you need to do it yourself, use the code below

# %%
from gseapy.plot import gseaplot, heatmap
terms = gs_res.res2d.index
for i in range(len(terms)):
    gseaplot(gs_res.ranking, term=terms[i], **gs_res.results[terms[i]],ofname=terms[i]+'.png')
